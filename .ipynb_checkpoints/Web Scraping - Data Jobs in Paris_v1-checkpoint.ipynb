# %% [markdown]
# # Web Scraping of "Welcome to the Jungle" for Data Jobs in Paris

# %% [markdown]
# ### Importing librairies and modules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import html5lib

# %% [markdown]
# ### Welcome to the Jungle website

# %% [markdown]
# Let's effectuate a research filtering with the criterias needed for my seach:
# - Your dream job? --> Data Analyst
# - Where? --> Paris

# %% [markdown]
# Therefore, here's the URL I will need to scrap:

# %%
URL = "https://csekhvms53-3.algolianet.com/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20vanilla%20JavaScript%20(lite)%203.24.12%3Breact-instantsearch%205.3.2%3BJS%20Helper%20(2.28.1)&x-algolia-application-id=CSEKHVMS53&x-algolia-api-key=02f0d440abc99cae37e126886438b266"

# %%
text = """accept: application/json
Accept-Encoding: gzip, deflate, br
Accept-Language: en-GB,en-US;q=0.9,en;q=0.8
Cache-Control: no-cache
Connection: keep-alive
Content-Length: 2049
content-type: application/x-www-form-urlencoded
Host: csekhvms53-3.algolianet.com
Origin: https://www.welcometothejungle.com
Pragma: no-cache
Referer: https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent
Sec-Fetch-Dest: empty
Sec-Fetch-Mode: cors
Sec-Fetch-Site: cross-site
User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36"""

# %%
headers = {h[0]:h[1] for x in text.split('\n') if (h := x.split(': '))}
headers
# Out:
# {'accept': 'application/json',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Content-Length': '2049',
#  'content-type': 'application/x-www-form-urlencoded',
#  'Host': 'csekhvms53-3.algolianet.com',
#  'Origin': 'https://www.welcometothejungle.com',
#  'Pragma': 'no-cache',
#  'Referer': 'https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent',
#  'Sec-Fetch-Dest': 'empty',
#  'Sec-Fetch-Mode': 'cors',
#  'Sec-Fetch-Site': 'cross-site',
#  'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}

# %%
# Since it is a POST request, I will need a "data" argument that I will call payload. The website call it "Form Data"
payload = """{"requests":[{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=30&maxValuesPerFacet=100&page=0&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&facets=%5B%22office.country_code%22%2C%22office.state%22%2C%22office.district%22%2C%22office.location%22%2C%22online%22%2C%22remote%22%2C%22contract_type_names.en%22%2C%22sectors.parent.en%22%2C%22profession.category.en%22%2C%22experience_level_minimum%22%2C%22organization.size.en%22%2C%22language%22%5D&tagFilters=&numericFilters=%5B%22experience_level_minimum%3E%3D0%22%2C%22experience_level_minimum%3C%3D15%22%5D"},{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=1&maxValuesPerFacet=100&page=0&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&attributesToRetrieve=%5B%5D&attributesToHighlight=%5B%5D&attributesToSnippet=%5B%5D&tagFilters=&analytics=false&clickAnalytics=false&facets=experience_level_minimum"}]}"""
payload[:500]
# Out:
# '{"requests":[{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=30&maxValuesPerFacet=100&page=0&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais'

# %%
response = requests.post(URL, headers=headers, data=payload)
response
# Out:
# <Response [200]>

# %%
data = response.json()["results"][0]["hits"]
data
# Out:
# [{'slug': 'senior-data-strategist_paris',
#   'name': 'Senior Data Strategist H/F CDI',
#   'profile': "Diplômé d’une école d’ingénieur ou de commerce, d’un Master en ingénierie informatique ou marketing.\r\nAu moins 3 ans d'expérience sur des sujets tag management, d’analyse de performance et / ou web analytics \r\n\r\n* Une bonne connaissance du Web en général, et des problématiques de performance business sur le Web en particulier\r\n* Rigoureux, organisé, avec un esprit de synthèse\r\n* Pragmatique, rationnel et curieux\r\n* La maîtrise ou connaissance des outils de data management (webanalyse, data viz, DMP,...)\r\n* La maîtrise ou connaissance de solutions d’optimisation de site (A/B testing, personnalisation…)\r\n* Une connaissance de techniques de processing de la donnée (ETL, engineering) est un plus\r\n* Une sensibilité aux sujets de transformation digitale est souhaitée\r\n* Aisance rédactionnelle et relationnelle\r\n* Une première expérience en management est un plus\r\n",
#   'language': 'fr',
#   'published_at': '2021-02-18T15:42:48.120+01:00',
#   'website': {'reference': 'wttj_fr'},
#   'reference': 'FABER_973JKVD',
#   'organization': {'name': 'FABERNOVEL',
#    'slug': 'fabernovel',
#    'reference': 'lMW728Z',
#    'size': {'fr': 'Entre 250 et 2000 salariés',
#     'en': 'Between 250 and 2,000 employees',
#     'es': 'Entre 250 y 2000 empleados',
#     'cs': 'Od 250 do 2 000 zaměstnanců',
#     'sk': 'Od 250 do 2 000 zamestnancov'},
#    'logo': {'url': 'https://cdn-images.welcometothejungle.com/m0KhXwu8DHITxv6zBM6iYmjogo2EgHD5yBz3_uODumw/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby83/NjM5LzE0ODE2MS9h/M2NiYmE3MS0wN2Rh/LTQzMTEtOGZhOC02/ZGFmOWUxZjNmNDku/cG5n',
#     'thumb': {'url': 'https://cdn-images.welcometothejungle.com/vD1cChXTOFrvjBK_iOHCxODmvOBhbgIMDRZYHeQ4LBg/w:70/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby83/NjM5LzE0ODE2MS9h/M2NiYmE3MS0wN2Rh/LTQzMTEtOGZhOC02/ZGFmOWUxZjNmNDku/cG5n'}},
#    'labels': [],
#    'cover_image': {'fr': {'url': 'https://cdn-images.welcometothejungle.com/ujwkrGfBDA1Ys4ZFgM_qEgZqTX7kOOpWuKwduBwiqtU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LWZhYmVybm92ZWwu/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/syX1iriRoEI15-dpFvWkNeKyYABXw-GCy0OZCSHSOyI/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LWZhYmVybm92ZWwu/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/NTeMVg_DJ0JxcsmjG_XnCqlFH5Tf232EyxRG1q35dfg/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LWZhYmVybm92ZWwu/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/LYKCg9KDgKAhjz17QDK1LHdELhST_R-s3bP_0AUF6Uw/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LWZhYmVybm92ZWwu/anBn'}},
#     'en': {'url': 'https://cdn-images.welcometothejungle.com/epXQV4noPGoGzB2d5S_AA5JgLEVJsSn4ToTnBSZYV7Q/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/tJmJTxOWN91qBoY3vX5mi1PXlUks0RLu1lOdjwLxrmI/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/XqXErz5KvRYB2Oj8A7VNf1CUIiAavj_Eh-ShpLvPn4A/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/q9n6x0kxejyXJZxBUMNrlB1zlw_zWXqkYrJXdZy78W4/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'}},
#     'es': {'url': 'https://cdn-images.welcometothejungle.com/epXQV4noPGoGzB2d5S_AA5JgLEVJsSn4ToTnBSZYV7Q/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/tJmJTxOWN91qBoY3vX5mi1PXlUks0RLu1lOdjwLxrmI/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/XqXErz5KvRYB2Oj8A7VNf1CUIiAavj_Eh-ShpLvPn4A/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/q9n6x0kxejyXJZxBUMNrlB1zlw_zWXqkYrJXdZy78W4/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'}},
#     'cs': {'url': 'https://cdn-images.welcometothejungle.com/epXQV4noPGoGzB2d5S_AA5JgLEVJsSn4ToTnBSZYV7Q/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/tJmJTxOWN91qBoY3vX5mi1PXlUks0RLu1lOdjwLxrmI/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/XqXErz5KvRYB2Oj8A7VNf1CUIiAavj_Eh-ShpLvPn4A/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/q9n6x0kxejyXJZxBUMNrlB1zlw_zWXqkYrJXdZy78W4/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'}},
#     'sk': {'url': 'https://cdn-images.welcometothejungle.com/epXQV4noPGoGzB2d5S_AA5JgLEVJsSn4ToTnBSZYV7Q/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/tJmJTxOWN91qBoY3vX5mi1PXlUks0RLu1lOdjwLxrmI/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/XqXErz5KvRYB2Oj8A7VNf1CUIiAavj_Eh-ShpLvPn4A/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/q9n6x0kxejyXJZxBUMNrlB1zlw_zWXqkYrJXdZy78W4/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LWZhYmVybm92ZWwu/anBn'}}},
#    'website_organization': {'slug': 'fabernovel'}},
#   'sectors': [{'name': {'fr': 'IT / Digital',
#      'en': 'IT / Digital',
#      'es': 'TI/Digital',
#      'cs': 'IT / Digital',
#      'sk': 'IT / Digitálne technológie'},
#     'parent': {'fr': 'Conseil / Audit',
#      'en': 'Consulting / Audit',
#      'es': 'Asesoría/Auditoría',
#      'cs': 'Poradenství a audit',
#      'sk': 'Poradenstvo a audit'}},
#    {'name': {'fr': 'Stratégie',
#      'en': 'Strategy',
#      'es': 'Estrategia',
#      'cs': 'Strategie',
#      'sk': 'Stratégia'},
#     'parent': {'fr': 'Conseil / Audit',
#      'en': 'Consulting / Audit',
#      'es': 'Asesoría/Auditoría',
#      'cs': 'Poradenství a audit',
#      'sk': 'Poradenstvo a audit'}},
#    {'name': {'fr': 'Transformation',
#      'en': 'Change Management',
#      'es': 'Gestión del cambio',
#      'cs': 'Change Management',
#      'sk': 'Manažment zmien'},
#     'parent': {'fr': 'Conseil / Audit',
#      'en': 'Consulting / Audit',
#      'es': 'Asesoría/Auditoría',
#      'cs': 'Poradenství a audit',
#      'sk': 'Poradenstvo a audit'}},
#    {'name': {'fr': 'Formation',
#      'en': 'Job Training',
#      'es': 'Formación',
#      'cs': 'Školení / Odborná příprava',
#      'sk': 'Odborná príprava'},
#     'parent': {'fr': 'Education / Formation / Recrutement',
#      'en': 'Education / Training / Recruitment',
#      'es': 'Educación/Formación/Selección de personal',
#      'cs': 'Vzdělávání / Školení / Recruitment',
#      'sk': 'Vzdelávanie / Školenie / Nábor zamestnancov'}}],
#   'sectors_name': {'fr': [{'Conseil / Audit': 'IT / Digital'},
#     {'Conseil / Audit': 'Stratégie'},
#     {'Conseil / Audit': 'Transformation'},
#     {'Education / Formation / Recrutement': 'Formation'}],
#    'en': [{'Consulting / Audit': 'IT / Digital'},
#     {'Consulting / Audit': 'Strategy'},
#     {'Consulting / Audit': 'Change Management'},
#     {'Education / Training / Recruitment': 'Job Training'}],
#    'es': [{'Asesoría/Auditoría': 'TI/Digital'},
#     {'Asesoría/Auditoría': 'Estrategia'},
#     {'Asesoría/Auditoría': 'Gestión del cambio'},
#     {'Educación/Formación/Selección de personal': 'Formación'}],
#    'cs': [{'Poradenství a audit': 'IT / Digital'},
#     {'Poradenství a audit': 'Strategie'},
#     {'Poradenství a audit': 'Change Management'},
#     {'Vzdělávání / Školení / Recruitment': 'Školení / Odborná příprava'}],
#    'sk': [{'Poradenstvo a audit': 'IT / Digitálne technológie'},
#     {'Poradenstvo a audit': 'Stratégia'},
#     {'Poradenstvo a audit': 'Manažment zmien'},
#     {'Vzdelávanie / Školenie / Nábor zamestnancov': 'Odborná príprava'}]},
#   'contract_type': 'FULL_TIME',
#   'contract_type_names': {'fr': 'CDI',
#    'en': 'Full-Time',
#    'es': 'Contrato indefinido',
#    'cs': 'Plný úvazek',
#    'sk': 'Zmluva na dobu neurčitú'},
#   'experience_level_minimum': 3,
#   'office': {'city': 'Paris',
#    'district': 'Paris',
#    'state': 'Ile-de-France',
#    'country': 'France',
#    'country_code': 'FR'},
#   'department': 'Marketing Digital',
#   'profession': {'name': {'fr': 'Data Analysis',
#     'en': 'Data Analysis',
#     'es': 'Análisis de datos',
#     'cs': 'Data Analysis',
#     'sk': 'Data Analysis'},
#    'category': {'fr': 'Tech',
#     'en': 'Tech',
#     'es': 'Tecnología',
#     'cs': 'Tech',
#     'sk': 'Technológie'}},
#   'profession_name': {'fr': {'Tech': 'Data Analysis'},
#    'en': {'Tech': 'Data Analysis'},
#    'es': {'Tecnología': 'Análisis de datos'},
#    'cs': {'Tech': 'Data Analysis'},
#    'sk': {'Technológie': 'Data Analysis'}},
#   'remote': 'punctual',
#   '_geoloc': {'lat': 48.87693429999999, 'lng': 2.3348912},
#   'objectID': '491884',
#   '_highlightResult': {'name': {'value': 'Senior <ais-highlight-0000000000>Data</ais-highlight-0000000000> Strategist H/F CDI',
#     'matchLevel': 'partial',
#     'fullyHighlighted': False,
#     'matchedWords': ['data']},
#    'profile': {'value': "Diplômé d’une école d’ingénieur ou de commerce, d’un Master en ingénierie informatique ou marketing.\r\nAu moins 3 ans d'expérience sur des sujets tag management, d’analyse de performance et / ou web analytics \r\n\r\n* Une bonne connaissance du Web en général, et des problématiques de performance business sur le Web en particulier\r\n* Rigoureux, organisé, avec un esprit de synthèse\r\n* Pragmatique, rationnel et curieux\r\n* La maîtrise ou connaissance des outils de <ais-highlight-0000000000>data</ais-highlight-0000000000> management (webanalyse, <ais-highlight-0000000000>data</ais-highlight-0000000000> viz, DMP,...)\r\n* La maîtrise ou connaissance de solutions d’optimisation de site (A/B testing, personnalisation…)\r\n* Une connaissance de techniques de processing de la donnée (ETL, engineering) est un plus\r\n* Une sensibilité aux sujets de transformation digitale est souhaitée\r\n* Aisance rédactionnelle et relationnelle\r\n* Une première expérience en management est un plus\r\n",
#     'matchLevel': 'partial',
#     'fullyHighlighted': False,
#     'matchedWords': ['data']},
#    'organization': {'name': {'value': 'FABERNOVEL',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'sectors': [{'name': {'fr': {'value': 'IT / Digital',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'IT / Digital',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'TI/Digital', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'IT / Digital',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'IT / Digitálne technológie',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Conseil / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Consulting / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Asesoría/Auditoría',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Poradenství a audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Poradenstvo a audit',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'Stratégie',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Strategy', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Estrategia', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Strategie', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Stratégia', 'matchLevel': 'none', 'matchedWords': []}},
#      'parent': {'fr': {'value': 'Conseil / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Consulting / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Asesoría/Auditoría',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Poradenství a audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Poradenstvo a audit',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'Transformation',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Change Management',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Gestión del cambio',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Change Management',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Manažment zmien',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Conseil / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Consulting / Audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Asesoría/Auditoría',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Poradenství a audit',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Poradenstvo a audit',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'Formation',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Job Training',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Formación', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Školení / Odborná příprava',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Odborná príprava',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Education / Formation / Recrutement',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Education / Training / Recruitment',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Educación/Formación/Selección de personal',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Vzdělávání / Školení / Recruitment',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Vzdelávanie / Školenie / Nábor zamestnancov',
#        'matchLevel': 'none',
#        'matchedWords': []}}}],
#    'contract_type_names': {'fr': {'value': 'CDI',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'en': {'value': 'Full-Time', 'matchLevel': 'none', 'matchedWords': []},
#     'es': {'value': 'Contrato indefinido',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'cs': {'value': 'Plný úvazek', 'matchLevel': 'none', 'matchedWords': []},
#     'sk': {'value': 'Zmluva na dobu neurčitú',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'office': {'city': {'value': 'Paris',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'district': {'value': 'Paris', 'matchLevel': 'none', 'matchedWords': []},
#     'state': {'value': 'Ile-de-France',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'country': {'value': 'France', 'matchLevel': 'none', 'matchedWords': []},
#     'country_code': {'value': 'FR', 'matchLevel': 'none', 'matchedWords': []}},
#    'department': {'value': 'Marketing Digital',
#     'matchLevel': 'none',
#     'matchedWords': []},
#    'profession': {'name': {'fr': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'en': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'es': {'value': 'Análisis de datos',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'cs': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'sk': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']}},
#     'category': {'fr': {'value': 'Tech',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'en': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#      'es': {'value': 'Tecnología', 'matchLevel': 'none', 'matchedWords': []},
#      'cs': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#      'sk': {'value': 'Technológie',
#       'matchLevel': 'none',
#       'matchedWords': []}}}}},
#  {'slug': 'senior-data-product-manager-h-f-cdi_paris',
#   'name': 'Senior Data Product Manager (H/F) - CDI - 🇫🇷',
#   'profile': "* Issu(e) d’une grande école d’ingénieur ou de commerce (X, Mines, Ponts, Télécom, Groupe des Ecoles Centrale, HEC, ESSEC, ESCP, etc.)\r\n* Passionné(e) de data et de digital\r\n* Hyper rigoureux(se), débrouillard(e) et indépendant(e)\r\n* Expérience en Project Management, idéalement dans le milieu du conseil, impliquant de nombreuses parties prenantes techniques et métiers\r\n* Connaissance du SQL et/ou de Python (en analyse de données)\r\n* A l'aise avec le traitement et la visualisation de données (Tableau, PowerBI, Data Studio, etc.)\r\n* Anglais courant\r\n\r\n**Les Plus**\r\n* Double parcours ingénieur-commerce\r\n* Expérience en Product Management (méthode agile) : formalisation des besoins, chiffrage, priorisation, gestion du backlog et de la roadmap, etc.\r\n* Exposition à un ou plusieurs outils de développement logiciel : Git, Visual Studio, Docker, etc.\r\n* Exposition à un ou plusieurs des outils Marketing suivants : Google AdWords, Google Analytics, CRM (Salesforce, Hubspot...), Segment, Fullstory, Intercom, etc.",
#   'language': 'fr',
#   'published_at': '2021-02-18T15:02:01.142+01:00',
#   'website': {'reference': 'wttj_fr'},
#   'reference': 'PAPER_KPZgMa0',
#   'organization': {'name': 'papernest',
#    'slug': 'souscritoo',
#    'reference': '3jRk35',
#    'size': {'fr': 'Entre 250 et 2000 salariés',
#     'en': 'Between 250 and 2,000 employees',
#     'es': 'Entre 250 y 2000 empleados',
#     'cs': 'Od 250 do 2 000 zaměstnanců',
#     'sk': 'Od 250 do 2 000 zamestnancov'},
#    'logo': {'url': 'https://cdn-images.welcometothejungle.com/-0PnaD7S-ljNzOJEU2nzoA-w-65RHhRcy8FcqBY8AHo/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby82/NTU3LzE0ODYzOS9l/NmY1YTBhOC1kOWU3/LTQ3NjUtOWZkNS03/Nzk4ZjY4NTQyOTQu/cG5n',
#     'thumb': {'url': 'https://cdn-images.welcometothejungle.com/YNpZwiZNShQbGxRlFOjw7_okLunp40f1VKdUI6xuEJI/w:70/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby82/NTU3LzE0ODYzOS9l/NmY1YTBhOC1kOWU3/LTQ3NjUtOWZkNS03/Nzk4ZjY4NTQyOTQu/cG5n'}},
#    'labels': [],
#    'cover_image': {'fr': {'url': 'https://cdn-images.welcometothejungle.com/2oYKhDQWi9Cmz0ASp0_14TnY2S13LdyHiqyY1ngeQeE/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/HdhL_qSsMhLM50vKX6koxbqD19XoIY6jjeNfsz8Pwy4/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/2ecNVq0vKTfpA-ZWo36wEgr3eAS6RoxvyDhaAFUC6Rw/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/XqcC1PY7H9Ph_QelWRg1A5V6mEO66olc1cPrQLWx5Mg/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'}},
#     'en': {'url': 'https://cdn-images.welcometothejungle.com/WTCm9FTVOcMIqLAkQ7xJyKg8yNbpdCTNhphGTipDl58/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LXNvdXNjcml0b28u/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/Q9OD5CXBzFJLDD5StIE2HsrQPl9PP_EjSiI2Xzl0ysc/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LXNvdXNjcml0b28u/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/Mra3GULKvKx1W580yrNoMPp1cZ4cI6ucmLHLX8FPmbg/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LXNvdXNjcml0b28u/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/2u9GvlNjjGjglNRU4QgMikcvkkPyH93uhfXC5y4CaGc/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vu/LXNvdXNjcml0b28u/anBn'}},
#     'es': {'url': 'https://cdn-images.welcometothejungle.com/YC3mkCrt-KXooHZHU9_yhEj3Lt5Lyy1Fsbo-wPd6KF8/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vz/LXNvdXNjcml0b28u/anBn',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/W3tIXDsTpEdeYoseTZkGunSeKN1OUC6n26KrbRqnSMw/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vz/LXNvdXNjcml0b28u/anBn'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/zGhijY22ES8UxSX9XzNcpnamhHO2SYDwpW9Kok69Dz4/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vz/LXNvdXNjcml0b28u/anBn'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/JCbBwmG0w7nid3Y-8vVyVNj0Y1poZfWbGz4-P6yo5EA/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Vz/LXNvdXNjcml0b28u/anBn'}},
#     'cs': {'url': 'https://cdn-images.welcometothejungle.com/2oYKhDQWi9Cmz0ASp0_14TnY2S13LdyHiqyY1ngeQeE/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/HdhL_qSsMhLM50vKX6koxbqD19XoIY6jjeNfsz8Pwy4/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/2ecNVq0vKTfpA-ZWo36wEgr3eAS6RoxvyDhaAFUC6Rw/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/XqcC1PY7H9Ph_QelWRg1A5V6mEO66olc1cPrQLWx5Mg/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'}},
#     'sk': {'url': 'https://cdn-images.welcometothejungle.com/2oYKhDQWi9Cmz0ASp0_14TnY2S13LdyHiqyY1ngeQeE/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/HdhL_qSsMhLM50vKX6koxbqD19XoIY6jjeNfsz8Pwy4/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/2ecNVq0vKTfpA-ZWo36wEgr3eAS6RoxvyDhaAFUC6Rw/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/XqcC1PY7H9Ph_QelWRg1A5V6mEO66olc1cPrQLWx5Mg/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL3Bh/cGVybmVzdC5qcGc'}}},
#    'website_organization': {'slug': 'papernest'}},
#   'sectors': [{'name': {'fr': 'Logiciels',
#      'en': 'Software',
#      'es': 'Software',
#      'cs': 'Software',
#      'sk': 'Softvér'},
#     'parent': {'fr': 'Tech',
#      'en': 'Tech',
#      'es': 'Tecnología',
#      'cs': 'Tech',
#      'sk': 'Technológie'}},
#    {'name': {'fr': 'E-commerce',
#      'en': 'E-commerce',
#      'es': 'Comercio electrónico',
#      'cs': 'E-commerce',
#      'sk': 'E-commerce'},
#     'parent': {'fr': 'Distribution',
#      'en': 'Distribution',
#      'es': 'Distribución',
#      'cs': 'Distribuce',
#      'sk': 'Distribúcia'}}],
#   'sectors_name': {'fr': [{'Tech': 'Logiciels'},
#     {'Distribution': 'E-commerce'}],
#    'en': [{'Tech': 'Software'}, {'Distribution': 'E-commerce'}],
#    'es': [{'Tecnología': 'Software'},
#     {'Distribución': 'Comercio electrónico'}],
#    'cs': [{'Tech': 'Software'}, {'Distribuce': 'E-commerce'}],
#    'sk': [{'Technológie': 'Softvér'}, {'Distribúcia': 'E-commerce'}]},
#   'contract_type': 'FULL_TIME',
#   'contract_type_names': {'fr': 'CDI',
#    'en': 'Full-Time',
#    'es': 'Contrato indefinido',
#    'cs': 'Plný úvazek',
#    'sk': 'Zmluva na dobu neurčitú'},
#   'experience_level_minimum': 2,
#   'office': {'city': 'Paris',
#    'district': 'Paris',
#    'state': 'Ile-de-France',
#    'country': 'France',
#    'country_code': 'FR'},
#   'department': 'Marketing & Growth',
#   'profession': {'name': {'fr': 'Data Analysis',
#     'en': 'Data Analysis',
#     'es': 'Análisis de datos',
#     'cs': 'Data Analysis',
#     'sk': 'Data Analysis'},
#    'category': {'fr': 'Tech',
#     'en': 'Tech',
#     'es': 'Tecnología',
#     'cs': 'Tech',
#     'sk': 'Technológie'}},
#   'profession_name': {'fr': {'Tech': 'Data Analysis'},
#    'en': {'Tech': 'Data Analysis'},
#    'es': {'Tecnología': 'Análisis de datos'},
#    'cs': {'Tech': 'Data Analysis'},
#    'sk': {'Technológie': 'Data Analysis'}},
#   'remote': 'partial',
#   '_geoloc': {'lat': 48.8981631, 'lng': 2.3780941},
#   'objectID': '493329',
#   '_highlightResult': {'name': {'value': 'Senior <ais-highlight-0000000000>Data</ais-highlight-0000000000> Product Manager (H/F) - CDI - 🇫🇷',
#     'matchLevel': 'partial',
#     'fullyHighlighted': False,
#     'matchedWords': ['data']},
#    'profile': {'value': "* Issu(e) d’une grande école d’ingénieur ou de commerce (X, Mines, Ponts, Télécom, Groupe des Ecoles Centrale, HEC, ESSEC, ESCP, etc.)\r\n* Passionné(e) de <ais-highlight-0000000000>data</ais-highlight-0000000000> et de digital\r\n* Hyper rigoureux(se), débrouillard(e) et indépendant(e)\r\n* Expérience en Project Management, idéalement dans le milieu du conseil, impliquant de nombreuses parties prenantes techniques et métiers\r\n* Connaissance du SQL et/ou de Python (en analyse de données)\r\n* A l'aise avec le traitement et la visualisation de données (Tableau, PowerBI, <ais-highlight-0000000000>Data</ais-highlight-0000000000> Studio, etc.)\r\n* Anglais courant\r\n\r\n**Les Plus**\r\n* Double parcours ingénieur-commerce\r\n* Expérience en Product Management (méthode agile) : formalisation des besoins, chiffrage, priorisation, gestion du backlog et de la roadmap, etc.\r\n* Exposition à un ou plusieurs outils de développement logiciel : Git, Visual Studio, Docker, etc.\r\n* Exposition à un ou plusieurs des outils Marketing suivants : Google AdWords, Google Analytics, CRM (Salesforce, Hubspot...), Segment, Fullstory, Intercom, etc.",
#     'matchLevel': 'partial',
#     'fullyHighlighted': False,
#     'matchedWords': ['data']},
#    'organization': {'name': {'value': 'papernest',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'sectors': [{'name': {'fr': {'value': 'Logiciels',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Software', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Software', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Software', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Softvér', 'matchLevel': 'none', 'matchedWords': []}},
#      'parent': {'fr': {'value': 'Tech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Tecnología', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Technológie',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'E-commerce',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'E-commerce', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Comercio electrónico',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'E-commerce', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'E-commerce', 'matchLevel': 'none', 'matchedWords': []}},
#      'parent': {'fr': {'value': 'Distribution',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Distribution',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Distribución',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Distribuce', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Distribúcia',
#        'matchLevel': 'none',
#        'matchedWords': []}}}],
#    'contract_type_names': {'fr': {'value': 'CDI',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'en': {'value': 'Full-Time', 'matchLevel': 'none', 'matchedWords': []},
#     'es': {'value': 'Contrato indefinido',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'cs': {'value': 'Plný úvazek', 'matchLevel': 'none', 'matchedWords': []},
#     'sk': {'value': 'Zmluva na dobu neurčitú',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'office': {'city': {'value': 'Paris',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'district': {'value': 'Paris', 'matchLevel': 'none', 'matchedWords': []},
#     'state': {'value': 'Ile-de-France',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'country': {'value': 'France', 'matchLevel': 'none', 'matchedWords': []},
#     'country_code': {'value': 'FR', 'matchLevel': 'none', 'matchedWords': []}},
#    'department': {'value': 'Marketing & Growth',
#     'matchLevel': 'none',
#     'matchedWords': []},
#    'profession': {'name': {'fr': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'en': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'es': {'value': 'Análisis de datos',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'cs': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']},
#      'sk': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analysi</ais-highlight-0000000000>s',
#       'matchLevel': 'full',
#       'fullyHighlighted': False,
#       'matchedWords': ['data', 'analyst']}},
#     'category': {'fr': {'value': 'Tech',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'en': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#      'es': {'value': 'Tecnología', 'matchLevel': 'none', 'matchedWords': []},
#      'cs': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#      'sk': {'value': 'Technológie',
#       'matchLevel': 'none',
#       'matchedWords': []}}}}},
#  {'slug': 'head-of-data-analytics_paris',
#   'name': 'Head of Data analytics',
#   'profile': '**Who are you?**\r\n\r\n*Must-have*\r\n\r\n* 8+ years of experience minimum, ideally from a serie B to D startup \r\n* You have a strong knowledge of modern stack data (snowflake, fivetrain, dbt..)\r\n* Highly analytical, you also have solid skills in Python, SQL and engineering\r\n* You have great communication skills\r\n* You already managed a team and know your basics in terms of hiring, people development, and coaching.\r\n\r\n*Nice-to-have *\r\n\r\n* GDPR knowledge\r\n* asynchronous & written skills\r\n* International profiles are more than welcome ! \r\n\r\n\r\n**What we offer**\r\n* Be part of the fastest growing insurtech in Europe\r\n* Benefit from a great equity plan\r\n* Nice perks (meal vouchers, unlimited days off, etc.)\r\n* Evolve in a stimulating and challenging environment\r\n* Share and learn with a passionate and diverse team\r\n* Friendly team and offices in Paris\r\n* Remote friendly company (from full to occasional remote possibilities)\r\n* We offer relocate package for non-french profiles that are willing to relocate ',
#   'language': 'en',
#   'published_at': '2021-02-18T14:32:21.564+01:00',
#   'website': {'reference': 'wttj_fr'},
#   'reference': 'LUKO_bV70ZAm',
#   'organization': {'name': 'Luko',
#    'slug': 'la-societe-demain-es-sas',
#    'reference': 'QaZy5Kz',
#    'size': {'fr': 'Entre 50 et 250 salariés',
#     'en': 'Between 50 and 250 employees',
#     'es': 'Entre 50 y 250 empleados',
#     'cs': 'Od 50 do 250 zaměstnanců',
#     'sk': 'Od 50 do 250 zamestnancov'},
#    'logo': {'url': 'https://cdn-images.welcometothejungle.com/lN3ziyio4DV6oXHBAFfvH6x8Ok7m3wAk_Bosnc7PRkk/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby81/NjA1LzE0OTg4Mi9j/OGY3MGU3Zi05Nzc5/LTQyM2EtYTEyZi0w/NGY1NGFiYzkwNTku/cG5n',
#     'thumb': {'url': 'https://cdn-images.welcometothejungle.com/VCOb3UE2lsxXabz76aYajVp4EdiSh9NX1nN0XAvyPWU/w:70/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby81/NjA1LzE0OTg4Mi9j/OGY3MGU3Zi05Nzc5/LTQyM2EtYTEyZi0w/NGY1NGFiYzkwNTku/cG5n'}},
#    'labels': [],
#    'cover_image': {'fr': {'url': 'https://cdn-images.welcometothejungle.com/TY_0hPCBOdtdtaL1xjS2sIOEcSwoNMvCjT3j4QPBFiQ/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/5VaOtE3pS-Q_RMRXFe4YNXjIYv1ILIiMJ2VYwg-YoYM/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/nbqRi7HY4ndCc4teJZdMcwe4_HuvK2YdmaAwfaV8uDM/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/J5YAt5dVzZGb21Ds3IPm4Lb0z59bqzJ8TEVu9GkxyKs/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'}},
#     'en': {'url': 'https://cdn-images.welcometothejungle.com/TY_0hPCBOdtdtaL1xjS2sIOEcSwoNMvCjT3j4QPBFiQ/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/5VaOtE3pS-Q_RMRXFe4YNXjIYv1ILIiMJ2VYwg-YoYM/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/nbqRi7HY4ndCc4teJZdMcwe4_HuvK2YdmaAwfaV8uDM/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/J5YAt5dVzZGb21Ds3IPm4Lb0z59bqzJ8TEVu9GkxyKs/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'}},
#     'es': {'url': 'https://cdn-images.welcometothejungle.com/TY_0hPCBOdtdtaL1xjS2sIOEcSwoNMvCjT3j4QPBFiQ/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/5VaOtE3pS-Q_RMRXFe4YNXjIYv1ILIiMJ2VYwg-YoYM/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/nbqRi7HY4ndCc4teJZdMcwe4_HuvK2YdmaAwfaV8uDM/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/J5YAt5dVzZGb21Ds3IPm4Lb0z59bqzJ8TEVu9GkxyKs/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'}},
#     'cs': {'url': 'https://cdn-images.welcometothejungle.com/TY_0hPCBOdtdtaL1xjS2sIOEcSwoNMvCjT3j4QPBFiQ/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/5VaOtE3pS-Q_RMRXFe4YNXjIYv1ILIiMJ2VYwg-YoYM/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/nbqRi7HY4ndCc4teJZdMcwe4_HuvK2YdmaAwfaV8uDM/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/J5YAt5dVzZGb21Ds3IPm4Lb0z59bqzJ8TEVu9GkxyKs/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'}},
#     'sk': {'url': 'https://cdn-images.welcometothejungle.com/TY_0hPCBOdtdtaL1xjS2sIOEcSwoNMvCjT3j4QPBFiQ/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/5VaOtE3pS-Q_RMRXFe4YNXjIYv1ILIiMJ2VYwg-YoYM/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/nbqRi7HY4ndCc4teJZdMcwe4_HuvK2YdmaAwfaV8uDM/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/J5YAt5dVzZGb21Ds3IPm4Lb0z59bqzJ8TEVu9GkxyKs/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Zy/LTM4M2ExZDk2LTAz/OWYtNGQ0MC1hMzU2/LTE5ODJmMzFlNzc0/Mi5qcGc'}}},
#    'website_organization': {'slug': 'luko'}},
#   'sectors': [{'name': {'fr': 'Intelligence artificielle / Machine Learning',
#      'en': 'Artificial Intelligence / Machine Learning',
#      'es': 'Inteligencia artificial/Aprendizaje automático',
#      'cs': 'Artificial Intelligence / Machine Learning',
#      'sk': 'Umelá inteligencia / Machine Learning'},
#     'parent': {'fr': 'Tech',
#      'en': 'Tech',
#      'es': 'Tecnología',
#      'cs': 'Tech',
#      'sk': 'Technológie'}},
#    {'name': {'fr': 'FinTech / InsurTech',
#      'en': 'FinTech / InsurTech',
#      'es': 'FinTech/InsurTech',
#      'cs': 'FinTech/InsurTech',
#      'sk': 'FinTech/InsurTech'},
#     'parent': {'fr': 'Banques / Assurances / Finance',
#      'en': 'Banking / Insurance / Finance',
#      'es': 'Banca/Seguros/Finanzas',
#      'cs': 'Bankovnictví / Pojišťovnictví / Finance',
#      'sk': 'Bankovníctvo / Poisťovníctvo / Financie'}}],
#   'sectors_name': {'fr': [{'Tech': 'Intelligence artificielle / Machine Learning'},
#     {'Banques / Assurances / Finance': 'FinTech / InsurTech'}],
#    'en': [{'Tech': 'Artificial Intelligence / Machine Learning'},
#     {'Banking / Insurance / Finance': 'FinTech / InsurTech'}],
#    'es': [{'Tecnología': 'Inteligencia artificial/Aprendizaje automático'},
#     {'Banca/Seguros/Finanzas': 'FinTech/InsurTech'}],
#    'cs': [{'Tech': 'Artificial Intelligence / Machine Learning'},
#     {'Bankovnictví / Pojišťovnictví / Finance': 'FinTech/InsurTech'}],
#    'sk': [{'Technológie': 'Umelá inteligencia / Machine Learning'},
#     {'Bankovníctvo / Poisťovníctvo / Financie': 'FinTech/InsurTech'}]},
#   'contract_type': 'FULL_TIME',
#   'contract_type_names': {'fr': 'CDI',
#    'en': 'Full-Time',
#    'es': 'Contrato indefinido',
#    'cs': 'Plný úvazek',
#    'sk': 'Zmluva na dobu neurčitú'},
#   'experience_level_minimum': 7,
#   'office': {'city': 'Paris',
#    'district': 'Paris',
#    'state': 'Ile-de-France',
#    'country': 'France',
#    'country_code': 'FR'},
#   'department': 'AI & Tech',
#   'profession': {'name': {'fr': 'Data Analysis',
#     'en': 'Data Analysis',
#     'es': 'Análisis de datos',
#     'cs': 'Data Analysis',
#     'sk': 'Data Analysis'},
#    'category': {'fr': 'Tech',
#     'en': 'Tech',
#     'es': 'Tecnología',
#     'cs': 'Tech',
#     'sk': 'Technológie'}},
#   'profession_name': {'fr': {'Tech': 'Data Analysis'},
#    'en': {'Tech': 'Data Analysis'},
#    'es': {'Tecnología': 'Análisis de datos'},
#    'cs': {'Tech': 'Data Analysis'},
#    'sk': {'Technológie': 'Data Analysis'}},
#   'remote': 'fulltime',
#   '_geoloc': {'lat': 48.87645, 'lng': 2.36503},
#   'objectID': '462020',
#   '_highlightResult': {'name': {'value': 'Head of <ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>analyt</ais-highlight-0000000000>ics',
#     'matchLevel': 'full',
#     'fullyHighlighted': False,
#     'matchedWords': ['data', 'analyst']},
#    'profile': {'value': '**Who are you?**\r\n\r\n*Must-have*\r\n\r\n* 8+ years of experience minimum, ideally from a serie B to D startup \r\n* You have a strong knowledge of modern stack <ais-highlight-0000000000>data</ais-highlight-0000000000> (snowflake, fivetrain, dbt..)\r\n* Highly <ais-highlight-0000000000>analyt</ais-highlight-0000000000>ical, you also have solid skills in Python, SQL and engineering\r\n* You have great communication skills\r\n* You already managed a team and know your basics in terms of hiring, people development, and coaching.\r\n\r\n*Nice-to-have *\r\n\r\n* GDPR knowledge\r\n* asynchronous & written skills\r\n* International profiles are more than welcome ! \r\n\r\n\r\n**What we offer**\r\n* Be part of the fastest growing insurtech in Europe\r\n* Benefit from a great equity plan\r\n* Nice perks (meal vouchers, unlimited days off, etc.)\r\n* Evolve in a stimulating and challenging environment\r\n* Share and learn with a passionate and diverse team\r\n* Friendly team and offices in Paris\r\n* Remote friendly company (from full to occasional remote possibilities)\r\n* We offer relocate package for non-french profiles that are willing to relocate ',
#     'matchLevel': 'full',
#     'fullyHighlighted': False,
#     'matchedWords': ['data', 'analyst']},
#    'organization': {'name': {'value': 'Luko',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'sectors': [{'name': {'fr': {'value': 'Intelligence artificielle / Machine Learning',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Artificial Intelligence / Machine Learning',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Inteligencia artificial/Aprendizaje automático',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Artificial Intelligence / Machine Learning',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Umelá inteligencia / Machine Learning',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Tech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Tecnología', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Tech', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Technológie',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'FinTech / InsurTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'FinTech / InsurTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'FinTech/InsurTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'FinTech/InsurTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'FinTech/InsurTech',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Banques / Assurances / Finance',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Banking / Insurance / Finance',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Banca/Seguros/Finanzas',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Bankovnictví / Pojišťovnictví / Finance',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Bankovníctvo / Poisťovníctvo / Financie',
#        'matchLevel': 'none',
#        'matchedWords': []}}}],
#    'contract_type_names': {'fr': {'value': 'CDI',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'en': {'value': 'Full-Time', 'matchLevel': 'none', 'matchedWords': []},
#     'es': {'value': 'Contrato indefinido',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'cs': {'value': 'Plný úvazek', 'matchLevel': 'none', 'matchedWords': []},
#     'sk': {'value': 'Zmluva na dobu neurčitú',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'office': {'city': {'value': 'Paris',
# ...
#    'slug': 'datawords',
#    'reference': '9AeNX8m',
#    'size': {'fr': 'Entre 250 et 2000 salariés',
#     'en': 'Between 250 and 2,000 employees',
#     'es': 'Entre 250 y 2000 empleados',
#     'cs': 'Od 250 do 2 000 zaměstnanců',
#     'sk': 'Od 250 do 2 000 zamestnancov'},
#    'logo': {'url': 'https://cdn-images.welcometothejungle.com/QJNvdUJFqWVGqOT77sn3JUydMGz15SZ9My_BlHYqbUE/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby81/Njk4LzE0OTkxOC9j/MWY4ZDQ1ZS05Yjk2/LTRkMzQtODA2Zi00/YTk2ODQ5ODgzZjUu/cG5n',
#     'thumb': {'url': 'https://cdn-images.welcometothejungle.com/qOfbkwIACrYOZcbzvfd6sVq-6LGcpmnKpXELm4OL8pg/w:70/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy9vcmdhbml6/YXRpb24vbG9nby81/Njk4LzE0OTkxOC9j/MWY4ZDQ1ZS05Yjk2/LTRkMzQtODA2Zi00/YTk2ODQ5ODgzZjUu/cG5n'}},
#    'labels': [],
#    'cover_image': {'fr': {'url': 'https://cdn-images.welcometothejungle.com/F7usX3uqSSszs5_97JpwKaPT574k8x3XQfYWTGgEZAU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/uQbeLFdLlcbikSVZEHigzgJFj1p2TdPB3YEeb22z1Cg/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xlXm9J4HKyFEmv_znyfECBDxFdL_vEh4Y7b0LWjxlQ8/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/Re4m3JX80rdDEuLToYjowF3Pa1Vd3iqDm0RmxAV2wwY/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'}},
#     'en': {'url': 'https://cdn-images.welcometothejungle.com/F7usX3uqSSszs5_97JpwKaPT574k8x3XQfYWTGgEZAU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/uQbeLFdLlcbikSVZEHigzgJFj1p2TdPB3YEeb22z1Cg/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xlXm9J4HKyFEmv_znyfECBDxFdL_vEh4Y7b0LWjxlQ8/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/Re4m3JX80rdDEuLToYjowF3Pa1Vd3iqDm0RmxAV2wwY/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'}},
#     'es': {'url': 'https://cdn-images.welcometothejungle.com/F7usX3uqSSszs5_97JpwKaPT574k8x3XQfYWTGgEZAU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/uQbeLFdLlcbikSVZEHigzgJFj1p2TdPB3YEeb22z1Cg/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xlXm9J4HKyFEmv_znyfECBDxFdL_vEh4Y7b0LWjxlQ8/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/Re4m3JX80rdDEuLToYjowF3Pa1Vd3iqDm0RmxAV2wwY/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'}},
#     'cs': {'url': 'https://cdn-images.welcometothejungle.com/F7usX3uqSSszs5_97JpwKaPT574k8x3XQfYWTGgEZAU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/uQbeLFdLlcbikSVZEHigzgJFj1p2TdPB3YEeb22z1Cg/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xlXm9J4HKyFEmv_znyfECBDxFdL_vEh4Y7b0LWjxlQ8/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/Re4m3JX80rdDEuLToYjowF3Pa1Vd3iqDm0RmxAV2wwY/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'}},
#     'sk': {'url': 'https://cdn-images.welcometothejungle.com/F7usX3uqSSszs5_97JpwKaPT574k8x3XQfYWTGgEZAU/w:2000/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc',
#      'large': {'url': 'https://cdn-images.welcometothejungle.com/uQbeLFdLlcbikSVZEHigzgJFj1p2TdPB3YEeb22z1Cg/w:1500/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'thumb': {'url': 'https://cdn-images.welcometothejungle.com/xlXm9J4HKyFEmv_znyfECBDxFdL_vEh4Y7b0LWjxlQ8/w:200/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'},
#      'small': {'url': 'https://cdn-images.welcometothejungle.com/Re4m3JX80rdDEuLToYjowF3Pa1Vd3iqDm0RmxAV2wwY/w:640/q:85/czM6Ly93dHRqLXBy/b2R1Y3Rpb24vdXBs/b2Fkcy93ZWJzaXRl/X29yZ2FuaXphdGlv/bi9jb3Zlcl9pbWFn/ZS93dHRqX2ZyL2Rh/dGF3b3Jkcy5qcGc'}}},
#    'website_organization': {'slug': 'datawords'}},
#   'sectors': [{'name': {'fr': 'Marketing / Communication',
#      'en': 'Marketing / Communications',
#      'es': 'Marketing/Comunicación',
#      'cs': 'Marketing a komunikace',
#      'sk': 'Marketing / Komunikácia'},
#     'parent': {'fr': 'Publicité / Marketing / Agence',
#      'en': 'Advertising / Marketing / Agency',
#      'es': 'Publicidad/Marketing/Agencia',
#      'cs': 'Advertising / Marketing / Agentury',
#      'sk': 'Reklama / Marketing / Agentúry'}},
#    {'name': {'fr': 'Digital',
#      'en': 'Digital',
#      'es': 'Digital',
#      'cs': 'Digital',
#      'sk': 'Digitálne technológie'},
#     'parent': {'fr': 'Publicité / Marketing / Agence',
#      'en': 'Advertising / Marketing / Agency',
#      'es': 'Publicidad/Marketing/Agencia',
#      'cs': 'Advertising / Marketing / Agentury',
#      'sk': 'Reklama / Marketing / Agentúry'}},
#    {'name': {'fr': 'AdTech  / MarTech',
#      'en': 'AdTech / MarTech',
#      'es': 'AdTech/MarTech',
#      'cs': 'AdTech / MarTech',
#      'sk': 'AdTech / MarTech'},
#     'parent': {'fr': 'Publicité / Marketing / Agence',
#      'en': 'Advertising / Marketing / Agency',
#      'es': 'Publicidad/Marketing/Agencia',
#      'cs': 'Advertising / Marketing / Agentury',
#      'sk': 'Reklama / Marketing / Agentúry'}}],
#   'sectors_name': {'fr': [{'Publicité / Marketing / Agence': 'Marketing / Communication'},
#     {'Publicité / Marketing / Agence': 'Digital'},
#     {'Publicité / Marketing / Agence': 'AdTech  / MarTech'}],
#    'en': [{'Advertising / Marketing / Agency': 'Marketing / Communications'},
#     {'Advertising / Marketing / Agency': 'Digital'},
#     {'Advertising / Marketing / Agency': 'AdTech / MarTech'}],
#    'es': [{'Publicidad/Marketing/Agencia': 'Marketing/Comunicación'},
#     {'Publicidad/Marketing/Agencia': 'Digital'},
#     {'Publicidad/Marketing/Agencia': 'AdTech/MarTech'}],
#    'cs': [{'Advertising / Marketing / Agentury': 'Marketing a komunikace'},
#     {'Advertising / Marketing / Agentury': 'Digital'},
#     {'Advertising / Marketing / Agentury': 'AdTech / MarTech'}],
#    'sk': [{'Reklama / Marketing / Agentúry': 'Marketing / Komunikácia'},
#     {'Reklama / Marketing / Agentúry': 'Digitálne technológie'},
#     {'Reklama / Marketing / Agentúry': 'AdTech / MarTech'}]},
#   'contract_type': 'FULL_TIME',
#   'contract_type_names': {'fr': 'CDI',
#    'en': 'Full-Time',
#    'es': 'Contrato indefinido',
#    'cs': 'Plný úvazek',
#    'sk': 'Zmluva na dobu neurčitú'},
#   'experience_level_minimum': 3,
#   'office': {'city': 'Levallois-perret',
#    'district': 'Hauts-de-Seine',
#    'state': 'Ile-de-France',
#    'country': 'France',
#    'country_code': 'FR'},
#   'department': None,
#   'profession': {'name': {'fr': 'Marketing',
#     'en': 'Marketing',
#     'es': 'Marketing',
#     'cs': 'Marketing',
#     'sk': 'Marketing'},
#    'category': {'fr': 'Marketing / Communication',
#     'en': 'Marketing / Communications',
#     'es': 'Marketing/Comunicación',
#     'cs': 'Marketing a komunikace',
#     'sk': 'Marketing / Komunikácia'}},
#   'profession_name': {'fr': {'Marketing / Communication': 'Marketing'},
#    'en': {'Marketing / Communications': 'Marketing'},
#    'es': {'Marketing/Comunicación': 'Marketing'},
#    'cs': {'Marketing a komunikace': 'Marketing'},
#    'sk': {'Marketing / Komunikácia': 'Marketing'}},
#   'remote': 'no',
#   '_geoloc': {'lat': 48.8879605, 'lng': 2.2822896},
#   'objectID': '464674',
#   '_highlightResult': {'name': {'value': '<ais-highlight-0000000000>Data</ais-highlight-0000000000> <ais-highlight-0000000000>Analyst</ais-highlight-0000000000> M/F',
#     'matchLevel': 'full',
#     'fullyHighlighted': False,
#     'matchedWords': ['data', 'analyst']},
#    'profile': {'value': '**Profil :**\r\n\r\n* Diplômé d’un master ou d’une école d’ingénieur en statistiques/informatique avec une première expérience en analyse de données.\r\n* La maitrise d’Excel est nécessaire, la connaissance d’outils d’Analytics est un fort avantage (GA, Adobe Analytics, …).\r\n* Connaissance d’au moins un outil de BI / Visualisation (Tableau, Power BI, Google <ais-highlight-0000000000>Data</ais-highlight-0000000000> Studio …) pour la création de présentations stratégiques.\r\n* Maitrise de SQL et connaissance d’au moins un langage de programmation orienté données (JS, VBA, python, R, ...).\r\n* Excellent(e) communicant(e), attentif au détail, bien organisé(e), force de proposition et fait preuve d’autonomie.\r\n* Esprit de synthèse et d’analyse affuté.\r\n* Excellente communication écrite et orale en anglais.\r\n* Bonne humeur et enthousiasme\r\n \r\n\r\n**Avantages :**\r\n\r\n* Environnement de travail international, au sein d’une société en très forte croissance.\r\n* Grands comptes internationaux dans le luxe, la mode, la cosmétique, les biens d’équipements, l’industrie etc.\r\n* Poste stratégique avec de forts enjeux pour nos clients.\r\n* Une équipe dynamique, soudée et positive.\r\n* Des activités fréquentes dans l’équipe.\r\n \r\n\r\n**Conditions :**\r\n\r\n* CDI basé à Levallois-Perret (92)\r\n* Rémunération selon profil\r\n* Poste à pourvoir immédiatement\r\n* Temps plein, 35h hebdomadaires',
#     'matchLevel': 'partial',
#     'fullyHighlighted': False,
#     'matchedWords': ['data']},
#    'organization': {'name': {'value': 'Datawords',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'sectors': [{'name': {'fr': {'value': 'Marketing / Communication',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Marketing / Communications',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Marketing/Comunicación',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Marketing a komunikace',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Marketing / Komunikácia',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Publicité / Marketing / Agence',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Advertising / Marketing / Agency',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Publicidad/Marketing/Agencia',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Advertising / Marketing / Agentury',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Reklama / Marketing / Agentúry',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'Digital',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Digital', 'matchLevel': 'none', 'matchedWords': []},
#       'es': {'value': 'Digital', 'matchLevel': 'none', 'matchedWords': []},
#       'cs': {'value': 'Digital', 'matchLevel': 'none', 'matchedWords': []},
#       'sk': {'value': 'Digitálne technológie',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Publicité / Marketing / Agence',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Advertising / Marketing / Agency',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Publicidad/Marketing/Agencia',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Advertising / Marketing / Agentury',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Reklama / Marketing / Agentúry',
#        'matchLevel': 'none',
#        'matchedWords': []}}},
#     {'name': {'fr': {'value': 'AdTech  / MarTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'AdTech / MarTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'AdTech/MarTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'AdTech / MarTech',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'AdTech / MarTech',
#        'matchLevel': 'none',
#        'matchedWords': []}},
#      'parent': {'fr': {'value': 'Publicité / Marketing / Agence',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'en': {'value': 'Advertising / Marketing / Agency',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'es': {'value': 'Publicidad/Marketing/Agencia',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'cs': {'value': 'Advertising / Marketing / Agentury',
#        'matchLevel': 'none',
#        'matchedWords': []},
#       'sk': {'value': 'Reklama / Marketing / Agentúry',
#        'matchLevel': 'none',
#        'matchedWords': []}}}],
#    'contract_type_names': {'fr': {'value': 'CDI',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'en': {'value': 'Full-Time', 'matchLevel': 'none', 'matchedWords': []},
#     'es': {'value': 'Contrato indefinido',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'cs': {'value': 'Plný úvazek', 'matchLevel': 'none', 'matchedWords': []},
#     'sk': {'value': 'Zmluva na dobu neurčitú',
#      'matchLevel': 'none',
#      'matchedWords': []}},
#    'office': {'city': {'value': 'Levallois-perret',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'district': {'value': 'Hauts-de-Seine',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'state': {'value': 'Ile-de-France',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'country': {'value': 'France', 'matchLevel': 'none', 'matchedWords': []},
#     'country_code': {'value': 'FR', 'matchLevel': 'none', 'matchedWords': []}},
#    'profession': {'name': {'fr': {'value': 'Marketing',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'en': {'value': 'Marketing', 'matchLevel': 'none', 'matchedWords': []},
#      'es': {'value': 'Marketing', 'matchLevel': 'none', 'matchedWords': []},
#      'cs': {'value': 'Marketing', 'matchLevel': 'none', 'matchedWords': []},
#      'sk': {'value': 'Marketing', 'matchLevel': 'none', 'matchedWords': []}},
#     'category': {'fr': {'value': 'Marketing / Communication',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'en': {'value': 'Marketing / Communications',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'es': {'value': 'Marketing/Comunicación',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'cs': {'value': 'Marketing a komunikace',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      'sk': {'value': 'Marketing / Komunikácia',
#       'matchLevel': 'none',
#       'matchedWords': []}}}}}]

# %%
df = pd.json_normalize(data)
df
# Out:
#                                                  slug  \
# 0                        senior-data-strategist_paris
# 1           senior-data-product-manager-h-f-cdi_paris
# 2                        head-of-data-analytics_paris
# 3                       acquisition-web-analyst_paris
# 4                        revenue-growth-analyst_paris
# 5                                  data-analyst_paris
# 6                business-analyst_paris_FAMOC_yRRporZ
# 7               consultant-data-scientist-h-f_puteaux
# 8   developpeur-se-fullstack-typescript-embedded-a...
# 9                           analyste-conformite_paris
# 10  senior-data-engineer-warehouse_paris_BLABL_7OQ...
# 11        data-scientist-bi-data-analytics-team_paris
# 12                                 data-analyst_paris
# 13     stage-supply-food-operations-analyst-h-f_paris
# 14        analyste-soc-niveau-3-h-f_neuilly-sur-seine
# 15       data-analyst-consultant-bi_neuilly-sur-seine
# 16                         product-data-analyst_paris
# 17                    business-data-analyst-h-f_paris
# 18                         business-analyst-m-f_paris
# 19  consultant-analytics-tracking-confirme-paris-h...
# 20                          data-analyst-stage_clichy
# 21                    stage-6-mois-data-analyst_paris
# 22             digital-analytics-consultant-h-f_paris
# 23  consultant-transformation-digitale-data-analyt...
# 24           customer-intelligence-manager-h-f_alsace
# 25                  stage-business-intelligence_paris
# 26             sales-development-representative_paris
# 27         data-scientist-analyst_paris_RELEV_AOLqRLw
# 28          pre-sales-cybersecurity-analyst-h-f_paris
# 29                  data-analyst-f-h_levallois-perret
#
#                                                  name  \
# 0                      Senior Data Strategist H/F CDI
# 1        Senior Data Product Manager (H/F) - CDI - 🇫🇷
# 2                              Head of Data analytics
# 3                             Acquisition Web Analyst
# 4                              Revenue Growth Analyst
# 5                                        Data Analyst
# 6                                    Business Analyst
# 7                     Consultant Data Scientist - H/F
# 8   Développeur·se Fullstack TypeScript - Embedded...
# 9                                 Analyste Conformité
# 10                   Senior Data Engineer - Warehouse
# 11          Data Scientist – BI & Data Analytics Team
# 12                       Data Analyst / Data Engineer
# 13     Stage - Supply & Food Operations Analyst (H/F)
# 14                          Analyste SOC Niveau 3 H/F
# 15                 Data Analyst & Consultant BI (H/F)
# 16                               Product Data Analyst
# 17                        Business Data Analyst (H/F)
# 18                             Business Analyst (M/F)
# 19  Consultant Analytics / Tracking Confirmé - Par...
# 20                               Data Analyst (Stage)
# 21                        Stage 6 mois : Data Analyst
# 22                   Digital Analytics Consultant H/F
# 23  CONSULTANT TRANSFORMATION DIGITALE - DATA & An...
# 24                  Customer Intelligence Manager H/F
# 25                      Business Intelligence (Stage)
# 26                  Sales Development Representative
# 27                             Data Scientist/Analyst
# 28                                  Pre-sales Analyst
# 29                                   Data Analyst M/F
#
#                                               profile language  \
# 0   Diplômé d’une école d’ingénieur ou de commerce...       fr
# 1   * Issu(e) d’une grande école d’ingénieur ou de...       fr
# 2   **Who are you?**\r\n\r\n*Must-have*\r\n\r\n* 8...       en
# 3   * **Experience**: You have 3+ years of experie...       en
# 4   * **Experience**: You have 3+ years of experie...       en
# 5   * **Experience**: You have 2-5 years of profes...       en
# 6   Votre profil :\r\n-\tVous étudiez pour un Mast...       en
# 7   **Qualifications**\r\n\r\nDiplômé d'une grande...       fr
# 8   **CODE**\r\n* Tu es à l'aise avec un **framewo...       fr
# 9   Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# 10  <p><strong>What you will need to be successful...       en
# 11  <p><strong>What we are looking for:</strong></...       en
# 12  **You could  be a good fit if:**\r\n* You've w...       en
# 13  ## **Votre expérience et vos qualités:**\r\n\r...       fr
# 14  Hard skills:\r\n\r\n•\tBac+4/5 en informatique...       fr
# 15  \tDe formation en Informatique décisionnelle\...       fr
# 16  **Hard Skills**\r\n* Tu as au moins 1 - 2 ans ...       fr
# 17  Dépêche toi de postuler si : \r\n* Tu as, envi...       fr
# 18  \r\n• You have at least 2 years of experience ...       en
# 19  **Ce qui va nous attirer ?**\r\n\r\nVotre dipl...       fr
# 20  Vous préparez un Bac +5 en analyse de données ...       fr
# 21  **Le candidat idéal :**\r\n* Compétences scien...       fr
# 22  Diplômé d’une grande école, vous avez une prem...       fr
# 23  Tu as au moins 3 ans d’expériences dans la mis...       fr
# 24  Votre profil\n\n•    Master avec 5 ans d’expér...       fr
# 25  - Tu es étudiant en grande école d’ingénieur (...       fr
# 26  - Passion for Growth : Vous êtes motivés par d...       fr
# 27  * Diplômé(e) d’une grande école d’ingénieur ou...       fr
# 28  **Requirements**\r\n* You are fluent or native...       fr
# 29  **Profil :**\r\n\r\n* Diplômé d’un master ou d...       fr
#
#                      published_at      reference  \
# 0   2021-02-18T15:42:48.120+01:00  FABER_973JKVD
# 1   2021-02-18T15:02:01.142+01:00  PAPER_KPZgMa0
# 2   2021-02-18T14:32:21.564+01:00   LUKO_bV70ZAm
# 3   2021-02-18T12:03:02.512+01:00  QONTO_6Rzo1pJ
# 4   2021-02-18T12:02:59.441+01:00  QONTO_mPx9mwA
# 5   2021-02-18T12:02:31.914+01:00  QONTO_AW2d8yw
# 6   2021-02-18T11:30:37.345+01:00  FAMOC_yRRporZ
# 7   2021-02-18T10:33:48.842+01:00  WAVES_rwq5Y20
# 8   2021-02-18T09:00:04.499+01:00     TT_p8AyYQj
# 9   2021-02-18T08:38:00.629+01:00  MOONC_ZqQNDG6
# 10  2021-02-17T23:05:45.992+01:00  BLABL_7OQXoAA
# 11  2021-02-17T23:00:08.617+01:00  DEEZE_g08MM3z
# 12  2021-02-17T18:56:17.885+01:00  SHIPU_AAd4qzP
# 13  2021-02-17T17:41:01.771+01:00  FRICH_NMYzKQ7
# 14  2021-02-17T16:55:03.886+01:00   LHSC_WwzXaZV
# 15  2021-02-17T16:54:50.634+01:00   LHSC_jJy8M2N
# 16  2021-02-17T16:41:34.771+01:00  SKELL_yLwVQO7
# 17  2021-02-17T16:40:32.368+01:00  SKELL_k7LRmd3
# 18  2021-02-17T16:05:08.650+01:00    DHS_JA54Rqg
# 19  2021-02-17T14:29:26.842+01:00   NIJI_LlD9Jy5
# 20  2021-02-17T13:50:36.815+01:00  TUCOE_zQjXYgN
# 21  2021-02-17T12:06:34.687+01:00  CITYS_2VzQMl5
# 22  2021-02-17T11:02:22.359+01:00  FIFTY_R1Aa2q8
# 23  2021-02-17T10:49:36.463+01:00     MA_qMxWAjq
# 24  2021-02-17T09:20:50.738+01:00     HG_D2W8Pz8
# 25  2021-02-17T08:43:57.925+01:00  SPACE_JDwNkbQ
# 26  2021-02-16T21:26:15.425+01:00     IA_PW2oaqm
# 27  2021-02-16T19:05:39.806+01:00  RELEV_AOLqRLw
# 28  2021-02-16T17:52:03.823+01:00  CYBEL_wqdbANo
# 29  2021-02-16T17:00:20.775+01:00  DATAW_NdwygxD
#
#                                               sectors contract_type  \
# 0   [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 1   [{'name': {'fr': 'Logiciels', 'en': 'Software'...     FULL_TIME
# 2   [{'name': {'fr': 'Intelligence artificielle / ...     FULL_TIME
# 3   [{'name': {'fr': 'FinTech / InsurTech', 'en': ...     FULL_TIME
# 4   [{'name': {'fr': 'FinTech / InsurTech', 'en': ...     FULL_TIME
# 5   [{'name': {'fr': 'FinTech / InsurTech', 'en': ...     FULL_TIME
# 6   [{'name': {'fr': 'Application mobile', 'en': '...    INTERNSHIP
# 7   [{'name': {'fr': 'Organisation / Management', ...     FULL_TIME
# 8   [{'name': {'fr': 'SaaS / Cloud Services', 'en'...     FULL_TIME
# 9   [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...     FULL_TIME
# 10  [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 11  [{'name': {'fr': 'Média', 'en': 'Media', 'es':...     FULL_TIME
# 12  [{'name': {'fr': 'Logistique', 'en': 'Logistic...     FULL_TIME
# 13  [{'name': {'fr': 'Restauration', 'en': 'Foodse...    INTERNSHIP
# 14  [{'name': {'fr': 'SaaS / Cloud Services', 'en'...     FULL_TIME
# 15  [{'name': {'fr': 'SaaS / Cloud Services', 'en'...     FULL_TIME
# 16  [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 17  [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 18  [{'name': {'fr': 'Digital Marketing / Data Mar...     FULL_TIME
# 19  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 20  [{'name': {'fr': 'Environnement / Développemen...    INTERNSHIP
# 21  [{'name': {'fr': 'Application mobile', 'en': '...    INTERNSHIP
# 22  [{'name': {'fr': 'Digital Marketing / Data Mar...     FULL_TIME
# 23  [{'name': {'fr': 'Organisation / Management', ...     FULL_TIME
# 24  [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 25  [{'name': {'fr': 'Logistique', 'en': 'Logistic...    INTERNSHIP
# 26  [{'name': {'fr': 'Digital Marketing / Data Mar...     FULL_TIME
# 27  [{'name': {'fr': 'Application mobile', 'en': '...     FULL_TIME
# 28  [{'name': {'fr': 'Big Data', 'en': 'Big Data',...     FULL_TIME
# 29  [{'name': {'fr': 'Marketing / Communication', ...     FULL_TIME
#
#     experience_level_minimum             department  ...  \
# 0                        3.0      Marketing Digital  ...
# 1                        2.0     Marketing & Growth  ...
# 2                        7.0              AI & Tech  ...
# 3                        3.0              Marketing  ...
# 4                        3.0              Marketing  ...
# 5                        2.0                   Tech  ...
# 6                        0.0                   None  ...
# 7                        0.0                   None  ...
# 8                        3.0                   Code  ...
# 9                        2.0       Customer Service  ...
# 10                       0.0                   None  ...
# 11                       0.0                   None  ...
# 12                       1.0                Product  ...
# 13                       0.0                 Stages  ...
# 14                       4.0                   None  ...
# 15                       0.0                   None  ...
# 16                       1.0                    Lab  ...
# 17                       2.0     Talent, admin et $  ...
# 18                       2.0        R&D and Product  ...
# 19                       3.0                   None  ...
# 20                       0.0                   Tech  ...
# 21                       0.0       Equipe Technique  ...
# 22                       0.0                   None  ...
# 23                       3.0       Data & Analytics  ...
# 24                       4.0                   None  ...
# 25                       0.0                Product  ...
# 26                       0.5                   None  ...
# 27                       1.0  Data, Produit et Tech  ...
# 28                       0.0                   None  ...
# 29                       3.0                   None  ...
#
#    profession_name.es.Asesoría profession_name.cs.Consulting  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                           NaN
# 6                          NaN                           NaN
# 7                          NaN                           NaN
# 8                          NaN                           NaN
# 9                          NaN                           NaN
# 10                         NaN                           NaN
# 11                         NaN                           NaN
# 12                         NaN                           NaN
# 13                         NaN                           NaN
# 14       TI/Project Management       IT / Project Management
# 15                         NaN                           NaN
# 16                         NaN                           NaN
# 17                         NaN                           NaN
# 18                         NaN                           NaN
# 19                         NaN                           NaN
# 20                         NaN                           NaN
# 21                         NaN                           NaN
# 22                     Digital                       Digital
# 23                  Innovación                       Inovace
# 24                         NaN                           NaN
# 25                         NaN                           NaN
# 26                         NaN                           NaN
# 27                         NaN                           NaN
# 28                         NaN                           NaN
# 29                         NaN                           NaN
#
#    profession_name.sk.Poradenstvo  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14      IT / Projektový manažment
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22          Digitálne technológie
# 23                       Inovácie
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
#
#    _highlightResult.department.fullyHighlighted profession_name.fr.Business  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
# 5                                           NaN                         NaN
# 6                                           NaN                         NaN
# 7                                           NaN                         NaN
# 8                                           NaN                         NaN
# 9                                           NaN                         NaN
# 10                                          NaN                         NaN
# 11                                          NaN                         NaN
# 12                                          NaN                         NaN
# 13                                          NaN                         NaN
# 14                                          NaN                         NaN
# 15                                          NaN                         NaN
# 16                                          NaN                         NaN
# 17                                          NaN                         NaN
# 18                                          NaN                         NaN
# 19                                          NaN                         NaN
# 20                                          NaN                         NaN
# 21                                          NaN                         NaN
# 22                                          NaN                         NaN
# 23                                        False                         NaN
# 24                                          NaN                         NaN
# 25                                          NaN                         NaN
# 26                                          NaN        Business Development
# 27                                        False                         NaN
# 28                                          NaN          Account Management
# 29                                          NaN                         NaN
#
#    profession_name.en.Business profession_name.es.Negocios  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                          NaN                         NaN
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 13                         NaN                         NaN
# 14                         NaN                         NaN
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                         NaN                         NaN
# 20                         NaN                         NaN
# 21                         NaN                         NaN
# 22                         NaN                         NaN
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                         NaN                         NaN
# 26        Business Development       Desarrollo de negocio
# 27                         NaN                         NaN
# 28          Account Management          Gestión de cuentas
# 29                         NaN                         NaN
#
#    profession_name.cs.Business profession_name.sk.Obchod  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 8                          NaN                       NaN
# 9                          NaN                       NaN
# 10                         NaN                       NaN
# 11                         NaN                       NaN
# 12                         NaN                       NaN
# 13                         NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
# 23                         NaN                       NaN
# 24                         NaN                       NaN
# 25                         NaN                       NaN
# 26        Business Development      Business Development
# 27                         NaN                       NaN
# 28          Account Management        Account Management
# 29                         NaN                       NaN
#
#    _highlightResult.organization.name.fullyHighlighted
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                              False
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 178 columns]

# %% [markdown]
# ## Understanding the data

# %%
df.shape
# Out:
# (30, 178)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 178 entries, slug to _highlightResult.organization.name.fullyHighlighted
# dtypes: float64(3), object(175)
# memory usage: 41.8+ KB

# %%
df.describe(include="all")
# Out:
#                       slug                  name  \
# count                   30                    30
# unique                  29                    30
# top     data-analyst_paris  Product Data Analyst
# freq                     2                     1
# mean                   NaN                   NaN
# std                    NaN                   NaN
# min                    NaN                   NaN
# 25%                    NaN                   NaN
# 50%                    NaN                   NaN
# 75%                    NaN                   NaN
# max                    NaN                   NaN
#
#                                                   profile language  \
# count                                                  30       30
# unique                                                 30        2
# top     Votre profil :\r\n-\tVous étudiez pour un Mast...       fr
# freq                                                    1       21
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#                          published_at      reference  \
# count                              30             30
# unique                             30             30
# top     2021-02-18T10:33:48.842+01:00  QONTO_6Rzo1pJ
# freq                                1              1
# mean                              NaN            NaN
# std                               NaN            NaN
# min                               NaN            NaN
# 25%                               NaN            NaN
# 50%                               NaN            NaN
# 75%                               NaN            NaN
# max                               NaN            NaN
#
#                                                   sectors contract_type  \
# count                                                  30            30
# unique                                                 26             2
# top     [{'name': {'fr': 'FinTech / InsurTech', 'en': ...     FULL_TIME
# freq                                                    3            25
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#         experience_level_minimum department  ... profession_name.es.Asesoría  \
# count                  30.000000         18  ...                           3
# unique                       NaN         15  ...                           3
# top                          NaN    Product  ...       TI/Project Management
# freq                         NaN          2  ...                           1
# mean                    1.650000        NaN  ...                         NaN
# std                     1.717807        NaN  ...                         NaN
# min                     0.000000        NaN  ...                         NaN
# 25%                     0.000000        NaN  ...                         NaN
# 50%                     1.500000        NaN  ...                         NaN
# 75%                     3.000000        NaN  ...                         NaN
# max                     7.000000        NaN  ...                         NaN
#
#        profession_name.cs.Consulting profession_name.sk.Poradenstvo  \
# count                              3                              3
# unique                             3                              3
# top                          Digital                       Inovácie
# freq                               1                              1
# mean                             NaN                            NaN
# std                              NaN                            NaN
# min                              NaN                            NaN
# 25%                              NaN                            NaN
# 50%                              NaN                            NaN
# 75%                              NaN                            NaN
# max                              NaN                            NaN
#
#        _highlightResult.department.fullyHighlighted  \
# count                                             2
# unique                                            1
# top                                           False
# freq                                              2
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        profession_name.fr.Business profession_name.en.Business  \
# count                            2                           2
# unique                           2                           2
# top             Account Management          Account Management
# freq                             1                           1
# mean                           NaN                         NaN
# std                            NaN                         NaN
# min                            NaN                         NaN
# 25%                            NaN                         NaN
# 50%                            NaN                         NaN
# 75%                            NaN                         NaN
# max                            NaN                         NaN
#
#        profession_name.es.Negocios profession_name.cs.Business  \
# count                            2                           2
# unique                           2                           2
# top          Desarrollo de negocio          Account Management
# freq                             1                           1
# mean                           NaN                         NaN
# std                            NaN                         NaN
# min                            NaN                         NaN
# 25%                            NaN                         NaN
# 50%                            NaN                         NaN
# 75%                            NaN                         NaN
# max                            NaN                         NaN
#
#        profession_name.sk.Obchod  \
# count                          2
# unique                         2
# top           Account Management
# freq                           1
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#        _highlightResult.organization.name.fullyHighlighted
# count                                                   1
# unique                                                  1
# top                                                 False
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 178 columns]

# %% [raw]
# df.dropna()
