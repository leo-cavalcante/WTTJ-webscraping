# %% [markdown]
# # Web Scraping of "Welcome to the Jungle" for Data Jobs in Paris

# %% [markdown]
# ### Importing librairies and modules

# %%
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Welcome to the Jungle website

# %% [markdown]
# Let's effectuate a research filtering with the criterias needed for my seach:
# - Your dream job? --> Data Analyst
# - Where? --> Paris

# %% [markdown]
# Therefore, here's the URL I will need to scrap:

# %%
URL = "https://csekhvms53-3.algolianet.com/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20vanilla%20JavaScript%20(lite)%203.24.12%3Breact-instantsearch%205.3.2%3BJS%20Helper%20(2.28.1)&x-algolia-application-id=CSEKHVMS53&x-algolia-api-key=02f0d440abc99cae37e126886438b266"

# %%
text = """accept: application/json
Accept-Encoding: gzip, deflate, br
Accept-Language: en-GB,en-US;q=0.9,en;q=0.8
Cache-Control: no-cache
Connection: keep-alive
Content-Length: 2049
content-type: application/x-www-form-urlencoded
Host: csekhvms53-3.algolianet.com
Origin: https://www.welcometothejungle.com
Pragma: no-cache
Referer: https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent
Sec-Fetch-Dest: empty
Sec-Fetch-Mode: cors
Sec-Fetch-Site: cross-site
User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36"""

# %%
headers = {h[0]:h[1] for x in text.split('\n') if (h := x.split(': '))}

headers
# Out:
# {'accept': 'application/json',
#  'Accept-Encoding': 'gzip, deflate, br',
#  'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Content-Length': '2049',
#  'content-type': 'application/x-www-form-urlencoded',
#  'Host': 'csekhvms53-3.algolianet.com',
#  'Origin': 'https://www.welcometothejungle.com',
#  'Pragma': 'no-cache',
#  'Referer': 'https://www.welcometothejungle.com/en/jobs?query=data%20analyst&page=1&aroundQuery=Paris%2C%20France&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&sortBy=mostRecent',
#  'Sec-Fetch-Dest': 'empty',
#  'Sec-Fetch-Mode': 'cors',
#  'Sec-Fetch-Site': 'cross-site',
#  'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}

# %%
# calculating the maximum number of pages for scraping
import numpy as np
totalpages=np.ceil(response.json()['results'][1]['nbHits']/30)
# Out:
# 10.0

# %%
# Since it is a POST request, I will need a "data" argument that I will call payload. The website call it "Form Data"
jobs = pd.DataFrame()
for i in range(totalpages):
    payload = """{"requests":[{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=30&maxValuesPerFacet=100&page="""+str(i)+"""&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&facets=%5B%22office.country_code%22%2C%22office.state%22%2C%22office.district%22%2C%22office.location%22%2C%22online%22%2C%22remote%22%2C%22contract_type_names.en%22%2C%22sectors.parent.en%22%2C%22profession.category.en%22%2C%22experience_level_minimum%22%2C%22organization.size.en%22%2C%22language%22%5D&tagFilters=&numericFilters=%5B%22experience_level_minimum%3E%3D0%22%2C%22experience_level_minimum%3C%3D15%22%5D"},{"indexName":"wk_cms_jobs_production_published_at_desc","params":"query=data%20analyst&hitsPerPage=1&maxValuesPerFacet=100&page=0&restrictSearchableAttributes=%5B%22name%22%2C%22profile%22%2C%22organization.name%22%2C%22office.city%22%2C%22office.district%22%2C%22office.state%22%2C%22office.country%22%2C%22department%22%2C%22profession.name.en%22%2C%22profession.category.en%22%2C%22contract_type_names.en%22%2C%22sectors.name.en%22%2C%22sectors.parent.en%22%5D&highlightPreTag=%3Cais-highlight-0000000000%3E&highlightPostTag=%3C%2Fais-highlight-0000000000%3E&aroundLatLng=48.85718%2C2.34141&aroundRadius=20000&aroundPrecision=20000&disableTypoToleranceOnAttributes=%5B%22profile%22%5D&filters=website.reference%3Awttj_fr&attributesToRetrieve=%5B%5D&attributesToHighlight=%5B%5D&attributesToSnippet=%5B%5D&tagFilters=&analytics=false&clickAnalytics=false&facets=experience_level_minimum"}]}"""
    response = requests.post(URL, headers=headers, data=payload)
    data = response.json()["results"][0]["hits"]
    jobs = pd.concat([jobs, pd.json_normalize(data)])
jobs
# Out:
#                                                  slug  \
# 0             lead-business-analyst-deliver-erp_paris
# 1             lead-business-analyst-finance-erp_paris
# 2   junior-business-operations-manager-stage-alter...
# 3             analyste-conformite_paris_MOONC_WaOlWMA
# 4                           analyste-conformite_paris
# ..                                                ...
# 25  stage-developpeur-euse-organisation-de-data-ch...
# 26                             business-analyst_paris
# 27        business-operations-data-analyst-h-f_clichy
# 28                       operations-analyst-h-f_paris
# 29                 traffic-manager-pre-embauche_paris
#
#                                                  name  \
# 0                  Lead, Business Analyst Deliver ERP
# 1                  Lead, Business Analyst Finance ERP
# 2       Junior Business Operations [stage/alternance]
# 3                                 Analyste Conformité
# 4                                 Analyste Conformité
# ..                                                ...
# 25  Stage -Développeur(euse) - organisation de Dat...
# 26                                   Business Analyst
# 27             Business Operations Data Analyst (H/F)
# 28                           Operations Analyst (H/F)
# 29                 Acquisition Manager (Pré-embauche)
#
#                                               profile language  \
# 0   * Bachelor’s degree in Information Technology,...       fr
# 1   * Bachelor’s degree in Information Technology,...       fr
# 2   - À la recherche d'une alternance ou d’un stag...       fr
# 3   Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# 4   Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ..                                                ...      ...
# 25  **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# 26  Vous êtes passionné(e) par les données, agile,...       fr
# 27  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# 28  **About you**\r\n\r\n* You are fluent and have...       en
# 29  - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                      published_at      reference  \
# 0   2021-02-19T12:57:57.889+01:00     JJ_XrAdwZp
# 1   2021-02-19T12:38:23.555+01:00     JJ_6687xGj
# 2   2021-02-19T11:13:59.409+01:00  BATCH_OLD82GY
# 3   2021-02-19T11:10:28.820+01:00  MOONC_WaOlWMA
# 4   2021-02-19T11:10:18.292+01:00  MOONC_ZqQNDG6
# ..                            ...            ...
# 25  2021-01-14T09:29:50.986+01:00    HDH_w76aAlZ
# 26  2021-01-13T22:15:10.808+01:00    OMC_NN7Wz17
# 27  2021-01-13T18:28:20.780+01:00  OPENI_1zRZkJM
# 28  2021-01-13T11:01:21.271+01:00  OWKIN_5GamajX
# 29  2021-01-12T18:08:16.849+01:00     IA_GAwe50z
#
#                                               sectors contract_type  \
# 0   [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...     FULL_TIME
# 1   [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...     FULL_TIME
# 2   [{'name': {'fr': 'Application mobile', 'en': '...    INTERNSHIP
# 3   [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...     FULL_TIME
# 4   [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...     FULL_TIME
# ..                                                ...           ...
# 25  [{'name': {'fr': 'Intelligence artificielle / ...    INTERNSHIP
# 26  [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...     FULL_TIME
# 27  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...     FULL_TIME
# 28  [{'name': {'fr': 'Intelligence artificielle / ...     FULL_TIME
# 29  [{'name': {'fr': 'Digital Marketing / Data Mar...    INTERNSHIP
#
#     experience_level_minimum             department  ...  \
# 0                        5.0                   None  ...
# 1                        5.0                   None  ...
# 2                        0.5                  Sales  ...
# 3                        2.0       Customer Service  ...
# 4                        2.0       Customer Service  ...
# ..                       ...                    ...  ...
# 25                       0.0  Direction des données  ...
# 26                       2.0                   None  ...
# 27                       2.0     Direction Générale  ...
# 28                       1.0             Operations  ...
# 29                       1.0                   None  ...
#
#    profession_name.es.Marketing/Comunicación  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                        Traffic Management
#
#    profession_name.cs.Marketing a komunikace  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                        Traffic Management
#
#    profession_name.sk.Marketing / Komunikácia  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                         Traffic Management
#
#    _highlightResult.department.fullyHighlighted  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#    _highlightResult.organization.name.fullyHighlighted  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 25                                              False
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                              False
#
#    profession_name.fr.Créa profession_name.en.Design  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ..                     ...                       ...
# 25                     NaN                       NaN
# 26                     NaN                       NaN
# 27                     NaN                       NaN
# 28                     NaN                       NaN
# 29                     NaN                       NaN
#
#    profession_name.es.Diseño y creatividad profession_name.cs.Design  \
# 0                                      NaN                       NaN
# 1                                      NaN                       NaN
# 2                                      NaN                       NaN
# 3                                      NaN                       NaN
# 4                                      NaN                       NaN
# ..                                     ...                       ...
# 25                                     NaN                       NaN
# 26                                     NaN                       NaN
# 27                                     NaN                       NaN
# 28                                     NaN                       NaN
# 29                                     NaN                       NaN
#
#    profession_name.sk.Dizajn
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
#
# [240 rows x 193 columns]

# %%
# Resetting index so it won't have any duplicates :
jobs = jobs.set_index("reference")

# %%
# In the previous step, the index has become a column, so I am going to get rid of this column:
#df.drop(columns="index", axis=1, inplace=True)
jobs
# Out:
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00
# ...                                      ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY  [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# ...                                                          ...
# HDH_w76aAlZ    [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17    [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX  [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z     [{'name': {'fr': 'Digital Marketing / Data Mar...
#
#               contract_type  experience_level_minimum             department  \
# reference
# JJ_XrAdwZp        FULL_TIME                       5.0                   None
# JJ_6687xGj        FULL_TIME                       5.0                   None
# BATCH_OLD82GY    INTERNSHIP                       0.5                  Sales
# MOONC_WaOlWMA     FULL_TIME                       2.0       Customer Service
# MOONC_ZqQNDG6     FULL_TIME                       2.0       Customer Service
# ...                     ...                       ...                    ...
# HDH_w76aAlZ      INTERNSHIP                       0.0  Direction des données
# OMC_NN7Wz17       FULL_TIME                       2.0                   None
# OPENI_1zRZkJM     FULL_TIME                       2.0     Direction Générale
# OWKIN_5GamajX     FULL_TIME                       1.0             Operations
# IA_GAwe50z       INTERNSHIP                       1.0                   None
#
#                  remote  ... profession_name.es.Marketing/Comunicación  \
# reference                ...
# JJ_XrAdwZp           no  ...                                       NaN
# JJ_6687xGj           no  ...                                       NaN
# BATCH_OLD82GY   partial  ...                                       NaN
# MOONC_WaOlWMA        no  ...                                       NaN
# MOONC_ZqQNDG6        no  ...                                       NaN
# ...                 ...  ...                                       ...
# HDH_w76aAlZ          no  ...                                       NaN
# OMC_NN7Wz17    punctual  ...                                       NaN
# OPENI_1zRZkJM   partial  ...                                       NaN
# OWKIN_5GamajX   partial  ...                                       NaN
# IA_GAwe50z      partial  ...                        Traffic Management
#
#               profession_name.cs.Marketing a komunikace  \
# reference
# JJ_XrAdwZp                                          NaN
# JJ_6687xGj                                          NaN
# BATCH_OLD82GY                                       NaN
# MOONC_WaOlWMA                                       NaN
# MOONC_ZqQNDG6                                       NaN
# ...                                                 ...
# HDH_w76aAlZ                                         NaN
# OMC_NN7Wz17                                         NaN
# OPENI_1zRZkJM                                       NaN
# OWKIN_5GamajX                                       NaN
# IA_GAwe50z                           Traffic Management
#
#               profession_name.sk.Marketing / Komunikácia  \
# reference
# JJ_XrAdwZp                                           NaN
# JJ_6687xGj                                           NaN
# BATCH_OLD82GY                                        NaN
# MOONC_WaOlWMA                                        NaN
# MOONC_ZqQNDG6                                        NaN
# ...                                                  ...
# HDH_w76aAlZ                                          NaN
# OMC_NN7Wz17                                          NaN
# OPENI_1zRZkJM                                        NaN
# OWKIN_5GamajX                                        NaN
# IA_GAwe50z                            Traffic Management
#
#               _highlightResult.department.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                             NaN
# JJ_6687xGj                                             NaN
# BATCH_OLD82GY                                          NaN
# MOONC_WaOlWMA                                          NaN
# MOONC_ZqQNDG6                                          NaN
# ...                                                    ...
# HDH_w76aAlZ                                            NaN
# OMC_NN7Wz17                                            NaN
# OPENI_1zRZkJM                                          NaN
# OWKIN_5GamajX                                          NaN
# IA_GAwe50z                                             NaN
#
#               _highlightResult.organization.name.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                  NaN
# OPENI_1zRZkJM                                                NaN
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                 False
#
#               profession_name.fr.Créa profession_name.en.Design  \
# reference
# JJ_XrAdwZp                        NaN                       NaN
# JJ_6687xGj                        NaN                       NaN
# BATCH_OLD82GY                     NaN                       NaN
# MOONC_WaOlWMA                     NaN                       NaN
# MOONC_ZqQNDG6                     NaN                       NaN
# ...                               ...                       ...
# HDH_w76aAlZ                       NaN                       NaN
# OMC_NN7Wz17                       NaN                       NaN
# OPENI_1zRZkJM                     NaN                       NaN
# OWKIN_5GamajX                     NaN                       NaN
# IA_GAwe50z                        NaN                       NaN
#
#               profession_name.es.Diseño y creatividad  \
# reference
# JJ_XrAdwZp                                        NaN
# JJ_6687xGj                                        NaN
# BATCH_OLD82GY                                     NaN
# MOONC_WaOlWMA                                     NaN
# MOONC_ZqQNDG6                                     NaN
# ...                                               ...
# HDH_w76aAlZ                                       NaN
# OMC_NN7Wz17                                       NaN
# OPENI_1zRZkJM                                     NaN
# OWKIN_5GamajX                                     NaN
# IA_GAwe50z                                        NaN
#
#               profession_name.cs.Design profession_name.sk.Dizajn
# reference
# JJ_XrAdwZp                          NaN                       NaN
# JJ_6687xGj                          NaN                       NaN
# BATCH_OLD82GY                       NaN                       NaN
# MOONC_WaOlWMA                       NaN                       NaN
# MOONC_ZqQNDG6                       NaN                       NaN
# ...                                 ...                       ...
# HDH_w76aAlZ                         NaN                       NaN
# OMC_NN7Wz17                         NaN                       NaN
# OPENI_1zRZkJM                       NaN                       NaN
# OWKIN_5GamajX                       NaN                       NaN
# IA_GAwe50z                          NaN                       NaN
#
# [240 rows x 192 columns]

# %% [markdown]
# ## Understanding the data

# %%
jobs.shape
# Out:
# (240, 192)

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, JJ_XrAdwZp to IA_GAwe50z
# Columns: 192 entries, slug to profession_name.sk.Dizajn
# dtypes: float64(3), object(189)
# memory usage: 361.9+ KB

# %%
jobs
# Out:
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00
# ...                                      ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY  [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# ...                                                          ...
# HDH_w76aAlZ    [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17    [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX  [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z     [{'name': {'fr': 'Digital Marketing / Data Mar...
#
#               contract_type  experience_level_minimum             department  \
# reference
# JJ_XrAdwZp        FULL_TIME                       5.0                   None
# JJ_6687xGj        FULL_TIME                       5.0                   None
# BATCH_OLD82GY    INTERNSHIP                       0.5                  Sales
# MOONC_WaOlWMA     FULL_TIME                       2.0       Customer Service
# MOONC_ZqQNDG6     FULL_TIME                       2.0       Customer Service
# ...                     ...                       ...                    ...
# HDH_w76aAlZ      INTERNSHIP                       0.0  Direction des données
# OMC_NN7Wz17       FULL_TIME                       2.0                   None
# OPENI_1zRZkJM     FULL_TIME                       2.0     Direction Générale
# OWKIN_5GamajX     FULL_TIME                       1.0             Operations
# IA_GAwe50z       INTERNSHIP                       1.0                   None
#
#                  remote  ... profession_name.es.Marketing/Comunicación  \
# reference                ...
# JJ_XrAdwZp           no  ...                                       NaN
# JJ_6687xGj           no  ...                                       NaN
# BATCH_OLD82GY   partial  ...                                       NaN
# MOONC_WaOlWMA        no  ...                                       NaN
# MOONC_ZqQNDG6        no  ...                                       NaN
# ...                 ...  ...                                       ...
# HDH_w76aAlZ          no  ...                                       NaN
# OMC_NN7Wz17    punctual  ...                                       NaN
# OPENI_1zRZkJM   partial  ...                                       NaN
# OWKIN_5GamajX   partial  ...                                       NaN
# IA_GAwe50z      partial  ...                        Traffic Management
#
#               profession_name.cs.Marketing a komunikace  \
# reference
# JJ_XrAdwZp                                          NaN
# JJ_6687xGj                                          NaN
# BATCH_OLD82GY                                       NaN
# MOONC_WaOlWMA                                       NaN
# MOONC_ZqQNDG6                                       NaN
# ...                                                 ...
# HDH_w76aAlZ                                         NaN
# OMC_NN7Wz17                                         NaN
# OPENI_1zRZkJM                                       NaN
# OWKIN_5GamajX                                       NaN
# IA_GAwe50z                           Traffic Management
#
#               profession_name.sk.Marketing / Komunikácia  \
# reference
# JJ_XrAdwZp                                           NaN
# JJ_6687xGj                                           NaN
# BATCH_OLD82GY                                        NaN
# MOONC_WaOlWMA                                        NaN
# MOONC_ZqQNDG6                                        NaN
# ...                                                  ...
# HDH_w76aAlZ                                          NaN
# OMC_NN7Wz17                                          NaN
# OPENI_1zRZkJM                                        NaN
# OWKIN_5GamajX                                        NaN
# IA_GAwe50z                            Traffic Management
#
#               _highlightResult.department.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                             NaN
# JJ_6687xGj                                             NaN
# BATCH_OLD82GY                                          NaN
# MOONC_WaOlWMA                                          NaN
# MOONC_ZqQNDG6                                          NaN
# ...                                                    ...
# HDH_w76aAlZ                                            NaN
# OMC_NN7Wz17                                            NaN
# OPENI_1zRZkJM                                          NaN
# OWKIN_5GamajX                                          NaN
# IA_GAwe50z                                             NaN
#
#               _highlightResult.organization.name.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                  NaN
# OPENI_1zRZkJM                                                NaN
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                 False
#
#               profession_name.fr.Créa profession_name.en.Design  \
# reference
# JJ_XrAdwZp                        NaN                       NaN
# JJ_6687xGj                        NaN                       NaN
# BATCH_OLD82GY                     NaN                       NaN
# MOONC_WaOlWMA                     NaN                       NaN
# MOONC_ZqQNDG6                     NaN                       NaN
# ...                               ...                       ...
# HDH_w76aAlZ                       NaN                       NaN
# OMC_NN7Wz17                       NaN                       NaN
# OPENI_1zRZkJM                     NaN                       NaN
# OWKIN_5GamajX                     NaN                       NaN
# IA_GAwe50z                        NaN                       NaN
#
#               profession_name.es.Diseño y creatividad  \
# reference
# JJ_XrAdwZp                                        NaN
# JJ_6687xGj                                        NaN
# BATCH_OLD82GY                                     NaN
# MOONC_WaOlWMA                                     NaN
# MOONC_ZqQNDG6                                     NaN
# ...                                               ...
# HDH_w76aAlZ                                       NaN
# OMC_NN7Wz17                                       NaN
# OPENI_1zRZkJM                                     NaN
# OWKIN_5GamajX                                     NaN
# IA_GAwe50z                                        NaN
#
#               profession_name.cs.Design profession_name.sk.Dizajn
# reference
# JJ_XrAdwZp                          NaN                       NaN
# JJ_6687xGj                          NaN                       NaN
# BATCH_OLD82GY                       NaN                       NaN
# MOONC_WaOlWMA                       NaN                       NaN
# MOONC_ZqQNDG6                       NaN                       NaN
# ...                                 ...                       ...
# HDH_w76aAlZ                         NaN                       NaN
# OMC_NN7Wz17                         NaN                       NaN
# OPENI_1zRZkJM                       NaN                       NaN
# OWKIN_5GamajX                       NaN                       NaN
# IA_GAwe50z                          NaN                       NaN
#
# [240 rows x 192 columns]

# %%
jobs.describe(include="all")
# Out:
#                       slug          name profile language  \
# count                  240           240     227      240
# unique                 227           217     217        2
# top     data-analyst_paris  Data Analyst               fr
# freq                    11            13       5      170
# mean                   NaN           NaN     NaN      NaN
# std                    NaN           NaN     NaN      NaN
# min                    NaN           NaN     NaN      NaN
# 25%                    NaN           NaN     NaN      NaN
# 50%                    NaN           NaN     NaN      NaN
# 75%                    NaN           NaN     NaN      NaN
# max                    NaN           NaN     NaN      NaN
#
#                          published_at  \
# count                             240
# unique                            240
# top     2021-01-14T15:56:01.175+01:00
# freq                                1
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
#                                                   sectors contract_type  \
# count                                                 240           240
# unique                                                132             5
# top     [{'name': {'fr': 'E-commerce', 'en': 'E-commer...     FULL_TIME
# freq                                                    9           178
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#         experience_level_minimum department remote  ...  \
# count                 240.000000        127    240  ...
# unique                       NaN         73      4  ...
# top                          NaN       Data     no  ...
# freq                         NaN         12    142  ...
# mean                    1.479167        NaN    NaN  ...
# std                     1.777234        NaN    NaN  ...
# min                     0.000000        NaN    NaN  ...
# 25%                     0.000000        NaN    NaN  ...
# 50%                     0.750000        NaN    NaN  ...
# 75%                     3.000000        NaN    NaN  ...
# max                    10.000000        NaN    NaN  ...
#
#        profession_name.es.Marketing/Comunicación  \
# count                                         16
# unique                                         5
# top                                    Marketing
# freq                                           6
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        profession_name.cs.Marketing a komunikace  \
# count                                         16
# unique                                         5
# top                                    Marketing
# freq                                           6
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        profession_name.sk.Marketing / Komunikácia  \
# count                                          16
# unique                                          5
# top                                     Marketing
# freq                                            6
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        _highlightResult.department.fullyHighlighted  \
# count                                            29
# unique                                            2
# top                                           False
# freq                                             17
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        _highlightResult.organization.name.fullyHighlighted  \
# count                                                   6
# unique                                                  1
# top                                                 False
# freq                                                    6
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        profession_name.fr.Créa profession_name.en.Design  \
# count                        1                         1
# unique                       1                         1
# top                  UI Design                 UI Design
# freq                         1                         1
# mean                       NaN                       NaN
# std                        NaN                       NaN
# min                        NaN                       NaN
# 25%                        NaN                       NaN
# 50%                        NaN                       NaN
# 75%                        NaN                       NaN
# max                        NaN                       NaN
#
#        profession_name.es.Diseño y creatividad profession_name.cs.Design  \
# count                                        1                         1
# unique                                       1                         1
# top                                  Diseño UI                 UI Design
# freq                                         1                         1
# mean                                       NaN                       NaN
# std                                        NaN                       NaN
# min                                        NaN                       NaN
# 25%                                        NaN                       NaN
# 50%                                        NaN                       NaN
# 75%                                        NaN                       NaN
# max                                        NaN                       NaN
#
#        profession_name.sk.Dizajn
# count                          1
# unique                         1
# top                    UI Design
# freq                           1
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
# [11 rows x 192 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Dropping all rows and columns that are filled with NaN results:
jobs.dropna(axis=0, how="all")
jobs.dropna(axis=1, how="all")
jobs.shape
# Out:
# (240, 192)

# %% [markdown]
# Good thing : the database doesn't have any empty rows nor columns.
# I will however **drop all columns that have at least 80% of NaN values**, because they are not significantly relevant:

# %%
# Criteria for the number of empty values to drop
number_of_rows = len(jobs.index)
number_of_rows*0.85
# Out:
# 192.0

# %%
# Dropping all rows and columns that are filled with NA results:
for column in jobs.columns:
    if jobs[column].isna().sum()>= 0.85*number_of_rows:
        jobs.drop(axis=0, columns=column, inplace=True)
print(jobs.shape)
jobs
# Out:
# (240, 182)
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00
# ...                                      ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY  [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# ...                                                          ...
# HDH_w76aAlZ    [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17    [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX  [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z     [{'name': {'fr': 'Digital Marketing / Data Mar...
#
#               contract_type  experience_level_minimum             department  \
# reference
# JJ_XrAdwZp        FULL_TIME                       5.0                   None
# JJ_6687xGj        FULL_TIME                       5.0                   None
# BATCH_OLD82GY    INTERNSHIP                       0.5                  Sales
# MOONC_WaOlWMA     FULL_TIME                       2.0       Customer Service
# MOONC_ZqQNDG6     FULL_TIME                       2.0       Customer Service
# ...                     ...                       ...                    ...
# HDH_w76aAlZ      INTERNSHIP                       0.0  Direction des données
# OMC_NN7Wz17       FULL_TIME                       2.0                   None
# OPENI_1zRZkJM     FULL_TIME                       2.0     Direction Générale
# OWKIN_5GamajX     FULL_TIME                       1.0             Operations
# IA_GAwe50z       INTERNSHIP                       1.0                   None
#
#                  remote  ...  \
# reference                ...
# JJ_XrAdwZp           no  ...
# JJ_6687xGj           no  ...
# BATCH_OLD82GY   partial  ...
# MOONC_WaOlWMA        no  ...
# MOONC_ZqQNDG6        no  ...
# ...                 ...  ...
# HDH_w76aAlZ          no  ...
# OMC_NN7Wz17    punctual  ...
# OPENI_1zRZkJM   partial  ...
# OWKIN_5GamajX   partial  ...
# IA_GAwe50z      partial  ...
#
#               _highlightResult.profession.name.en.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                False
# OPENI_1zRZkJM                                              False
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                   NaN
#
#               _highlightResult.profession.name.cs.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                False
# OPENI_1zRZkJM                                              False
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                   NaN
#
#               _highlightResult.profession.name.sk.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                False
# OPENI_1zRZkJM                                              False
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                   NaN
#
#               profession_name.fr.Marketing / Communication  \
# reference
# JJ_XrAdwZp                                             NaN
# JJ_6687xGj                                             NaN
# BATCH_OLD82GY                                          NaN
# MOONC_WaOlWMA                                          NaN
# MOONC_ZqQNDG6                                          NaN
# ...                                                    ...
# HDH_w76aAlZ                                            NaN
# OMC_NN7Wz17                                            NaN
# OPENI_1zRZkJM                                          NaN
# OWKIN_5GamajX                                          NaN
# IA_GAwe50z                              Traffic Management
#
#               profession_name.en.Marketing / Communications  \
# reference
# JJ_XrAdwZp                                              NaN
# JJ_6687xGj                                              NaN
# BATCH_OLD82GY                                           NaN
# MOONC_WaOlWMA                                           NaN
# MOONC_ZqQNDG6                                           NaN
# ...                                                     ...
# HDH_w76aAlZ                                             NaN
# OMC_NN7Wz17                                             NaN
# OPENI_1zRZkJM                                           NaN
# OWKIN_5GamajX                                           NaN
# IA_GAwe50z                               Traffic Management
#
#               profession_name.es.Marketing/Comunicación  \
# reference
# JJ_XrAdwZp                                          NaN
# JJ_6687xGj                                          NaN
# BATCH_OLD82GY                                       NaN
# MOONC_WaOlWMA                                       NaN
# MOONC_ZqQNDG6                                       NaN
# ...                                                 ...
# HDH_w76aAlZ                                         NaN
# OMC_NN7Wz17                                         NaN
# OPENI_1zRZkJM                                       NaN
# OWKIN_5GamajX                                       NaN
# IA_GAwe50z                           Traffic Management
#
#               profession_name.cs.Marketing a komunikace  \
# reference
# JJ_XrAdwZp                                          NaN
# JJ_6687xGj                                          NaN
# BATCH_OLD82GY                                       NaN
# MOONC_WaOlWMA                                       NaN
# MOONC_ZqQNDG6                                       NaN
# ...                                                 ...
# HDH_w76aAlZ                                         NaN
# OMC_NN7Wz17                                         NaN
# OPENI_1zRZkJM                                       NaN
# OWKIN_5GamajX                                       NaN
# IA_GAwe50z                           Traffic Management
#
#               profession_name.sk.Marketing / Komunikácia  \
# reference
# JJ_XrAdwZp                                           NaN
# JJ_6687xGj                                           NaN
# BATCH_OLD82GY                                        NaN
# MOONC_WaOlWMA                                        NaN
# MOONC_ZqQNDG6                                        NaN
# ...                                                  ...
# HDH_w76aAlZ                                          NaN
# OMC_NN7Wz17                                          NaN
# OPENI_1zRZkJM                                        NaN
# OWKIN_5GamajX                                        NaN
# IA_GAwe50z                            Traffic Management
#
#               _highlightResult.department.fullyHighlighted  \
# reference
# JJ_XrAdwZp                                             NaN
# JJ_6687xGj                                             NaN
# BATCH_OLD82GY                                          NaN
# MOONC_WaOlWMA                                          NaN
# MOONC_ZqQNDG6                                          NaN
# ...                                                    ...
# HDH_w76aAlZ                                            NaN
# OMC_NN7Wz17                                            NaN
# OPENI_1zRZkJM                                          NaN
# OWKIN_5GamajX                                          NaN
# IA_GAwe50z                                             NaN
#
#               _highlightResult.organization.name.fullyHighlighted
# reference
# JJ_XrAdwZp                                                   NaN
# JJ_6687xGj                                                   NaN
# BATCH_OLD82GY                                                NaN
# MOONC_WaOlWMA                                                NaN
# MOONC_ZqQNDG6                                                NaN
# ...                                                          ...
# HDH_w76aAlZ                                                False
# OMC_NN7Wz17                                                  NaN
# OPENI_1zRZkJM                                                NaN
# OWKIN_5GamajX                                                NaN
# IA_GAwe50z                                                 False
#
# [240 rows x 182 columns]

# %% [markdown]
# ### Cleaning columns columns that show duplicated content in other languages other than English:

# %%
# Identifying all the columns :
col = []
for language in [".cs", ".es", ".fr", ".sk"]:
    col += [c for c in jobs.columns if language in c]
col
# Out:
# ['organization.size.cs',
#  'organization.cover_image.cs.url',
#  'organization.cover_image.cs.large.url',
#  'organization.cover_image.cs.thumb.url',
#  'organization.cover_image.cs.small.url',
#  'sectors_name.cs',
#  'contract_type_names.cs',
#  'profession.name.cs',
#  'profession.category.cs',
#  'profession_name.cs.Business',
#  '_highlightResult.contract_type_names.cs.value',
#  '_highlightResult.contract_type_names.cs.matchLevel',
#  '_highlightResult.contract_type_names.cs.matchedWords',
#  '_highlightResult.profession.name.cs.value',
#  '_highlightResult.profession.name.cs.matchLevel',
#  '_highlightResult.profession.name.cs.matchedWords',
#  '_highlightResult.profession.category.cs.value',
#  '_highlightResult.profession.category.cs.matchLevel',
#  '_highlightResult.profession.category.cs.matchedWords',
#  'profession_name.cs.Consulting',
#  'profession_name.cs.Podpora',
#  'profession_name.cs.Audit / Finance / Pojišťovnictví',
#  'profession_name.cs.Tech',
#  '_highlightResult.profession.name.cs.fullyHighlighted',
#  'profession_name.cs.Marketing a komunikace',
#  'organization.size.es',
#  'organization.cover_image.es.url',
#  'organization.cover_image.es.large.url',
#  'organization.cover_image.es.thumb.url',
#  'organization.cover_image.es.small.url',
#  'sectors_name.es',
#  'contract_type_names.es',
#  'profession.name.es',
#  'profession.category.es',
#  'profession_name.es.Negocios',
#  '_highlightResult.contract_type_names.es.value',
#  '_highlightResult.contract_type_names.es.matchLevel',
#  '_highlightResult.contract_type_names.es.matchedWords',
#  '_highlightResult.profession.name.es.value',
#  '_highlightResult.profession.name.es.matchLevel',
#  '_highlightResult.profession.name.es.matchedWords',
#  '_highlightResult.profession.category.es.value',
#  '_highlightResult.profession.category.es.matchLevel',
#  '_highlightResult.profession.category.es.matchedWords',
#  'profession_name.es.Asesoría',
#  'profession_name.es.Servicios generales',
#  'profession_name.es.Auditoría/Finanzas/Seguros',
#  'profession_name.es.Tecnología',
#  'profession_name.es.Marketing/Comunicación',
#  'organization.size.fr',
#  'organization.cover_image.fr.url',
#  'organization.cover_image.fr.large.url',
#  'organization.cover_image.fr.thumb.url',
#  'organization.cover_image.fr.small.url',
#  'sectors_name.fr',
#  'contract_type_names.fr',
#  'profession.name.fr',
#  'profession.category.fr',
#  'profession_name.fr.Business',
#  '_highlightResult.contract_type_names.fr.value',
#  '_highlightResult.contract_type_names.fr.matchLevel',
#  '_highlightResult.contract_type_names.fr.matchedWords',
#  '_highlightResult.profession.name.fr.value',
#  '_highlightResult.profession.name.fr.matchLevel',
#  '_highlightResult.profession.name.fr.matchedWords',
#  '_highlightResult.profession.category.fr.value',
#  '_highlightResult.profession.category.fr.matchLevel',
#  '_highlightResult.profession.category.fr.matchedWords',
#  'profession_name.fr.Conseil',
#  'profession_name.fr.Support',
#  'profession_name.fr.Audit / Finance / Assurance',
#  'profession_name.fr.Tech',
#  '_highlightResult.profession.name.fr.fullyHighlighted',
#  'profession_name.fr.Marketing / Communication',
#  'organization.size.sk',
#  'organization.cover_image.sk.url',
#  'organization.cover_image.sk.large.url',
#  'organization.cover_image.sk.thumb.url',
#  'organization.cover_image.sk.small.url',
#  'sectors_name.sk',
#  'contract_type_names.sk',
#  'profession.name.sk',
#  'profession.category.sk',
#  'profession_name.sk.Obchod',
#  '_highlightResult.contract_type_names.sk.value',
#  '_highlightResult.contract_type_names.sk.matchLevel',
#  '_highlightResult.contract_type_names.sk.matchedWords',
#  '_highlightResult.profession.name.sk.value',
#  '_highlightResult.profession.name.sk.matchLevel',
#  '_highlightResult.profession.name.sk.matchedWords',
#  '_highlightResult.profession.category.sk.value',
#  '_highlightResult.profession.category.sk.matchLevel',
#  '_highlightResult.profession.category.sk.matchedWords',
#  'profession_name.sk.Poradenstvo',
#  'profession_name.sk.Podpora',
#  'profession_name.sk.Audit / Financie / Poisťovníctvo',
#  'profession_name.sk.Technológie',
#  '_highlightResult.profession.name.sk.fullyHighlighted',
#  'profession_name.sk.Marketing / Komunikácia']

# %%
len(col)
# Out:
# 99

# %%
# Finally droping the columns in other languages
jobs.drop(axis=1, columns=col, inplace=True)
jobs.shape
# Out:
# (240, 83)

# %%
# Printing the new columns of our DataFrame
col = [c for c in jobs.columns]
col
# Out:
# ['slug',
#  'name',
#  'profile',
#  'language',
#  'published_at',
#  'sectors',
#  'contract_type',
#  'experience_level_minimum',
#  'department',
#  'remote',
#  'objectID',
#  'website.reference',
#  'organization.name',
#  'organization.slug',
#  'organization.reference',
#  'organization.size.en',
#  'organization.logo.url',
#  'organization.logo.thumb.url',
#  'organization.labels',
#  'organization.cover_image.en.url',
#  'organization.cover_image.en.large.url',
#  'organization.cover_image.en.thumb.url',
#  'organization.cover_image.en.small.url',
#  'organization.website_organization.slug',
#  'sectors_name.en',
#  'contract_type_names.en',
#  'office.city',
#  'office.district',
#  'office.state',
#  'office.country',
#  'office.country_code',
#  'profession.name.en',
#  'profession.category.en',
#  'profession_name.en.Business',
#  '_geoloc.lat',
#  '_geoloc.lng',
#  '_highlightResult.name.value',
#  '_highlightResult.name.matchLevel',
#  '_highlightResult.name.fullyHighlighted',
#  '_highlightResult.name.matchedWords',
#  '_highlightResult.profile.value',
#  '_highlightResult.profile.matchLevel',
#  '_highlightResult.profile.fullyHighlighted',
#  '_highlightResult.profile.matchedWords',
#  '_highlightResult.organization.name.value',
#  '_highlightResult.organization.name.matchLevel',
#  '_highlightResult.organization.name.matchedWords',
#  '_highlightResult.sectors',
#  '_highlightResult.contract_type_names.en.value',
#  '_highlightResult.contract_type_names.en.matchLevel',
#  '_highlightResult.contract_type_names.en.matchedWords',
#  '_highlightResult.office.city.value',
#  '_highlightResult.office.city.matchLevel',
#  '_highlightResult.office.city.matchedWords',
#  '_highlightResult.office.district.value',
#  '_highlightResult.office.district.matchLevel',
#  '_highlightResult.office.district.matchedWords',
#  '_highlightResult.office.state.value',
#  '_highlightResult.office.state.matchLevel',
#  '_highlightResult.office.state.matchedWords',
#  '_highlightResult.office.country.value',
#  '_highlightResult.office.country.matchLevel',
#  '_highlightResult.office.country.matchedWords',
#  '_highlightResult.office.country_code.value',
#  '_highlightResult.office.country_code.matchLevel',
#  '_highlightResult.office.country_code.matchedWords',
#  '_highlightResult.profession.name.en.value',
#  '_highlightResult.profession.name.en.matchLevel',
#  '_highlightResult.profession.name.en.matchedWords',
#  '_highlightResult.profession.category.en.value',
#  '_highlightResult.profession.category.en.matchLevel',
#  '_highlightResult.profession.category.en.matchedWords',
#  'profession_name.en.Consulting',
#  'profession_name.en.Support Roles',
#  '_highlightResult.department.value',
#  '_highlightResult.department.matchLevel',
#  '_highlightResult.department.matchedWords',
#  'profession_name.en.Audit / Finance / Insurance',
#  'profession_name.en.Tech',
#  '_highlightResult.profession.name.en.fullyHighlighted',
#  'profession_name.en.Marketing / Communications',
#  '_highlightResult.department.fullyHighlighted',
#  '_highlightResult.organization.name.fullyHighlighted']

# %% [markdown]
# ### Droping all the "Organization" columns that don't interest me:

# %%
col = ['organization.slug', 'organization.logo.url', 'organization.logo.thumb.url', 'organization.labels',
 'organization.cover_image.en.url', 'organization.cover_image.en.large.url', 'organization.cover_image.en.thumb.url',
 'organization.cover_image.en.small.url', 'organization.website_organization.slug']

# %%
jobs.drop(axis=1, columns=col, inplace=True)
jobs.shape
# Out:
# (240, 74)

# %% [markdown]
# ### Droping columns starting with "_highlightResults" that might not interest me:

# %%
col = ['_highlightResult.name.value',
 '_highlightResult.name.matchLevel',
 '_highlightResult.name.fullyHighlighted',
 '_highlightResult.name.matchedWords',
 '_highlightResult.profile.value',
 '_highlightResult.profile.matchLevel',
 '_highlightResult.profile.fullyHighlighted',
 '_highlightResult.profile.matchedWords',
 '_highlightResult.organization.name.value',
 '_highlightResult.organization.name.matchLevel',
 '_highlightResult.organization.name.matchedWords',
 '_highlightResult.sectors',
 '_highlightResult.contract_type_names.en.value',
 '_highlightResult.contract_type_names.en.matchLevel',
 '_highlightResult.contract_type_names.en.matchedWords',
 '_highlightResult.office.city.value',
 '_highlightResult.office.city.matchLevel',
 '_highlightResult.office.city.matchedWords',
 '_highlightResult.office.district.value',
 '_highlightResult.office.district.matchLevel',
 '_highlightResult.office.district.matchedWords',
 '_highlightResult.office.state.value',
 '_highlightResult.office.state.matchLevel',
 '_highlightResult.office.state.matchedWords',
 '_highlightResult.office.country.value',
 '_highlightResult.office.country.matchLevel',
 '_highlightResult.office.country.matchedWords',
 '_highlightResult.office.country_code.value',
 '_highlightResult.office.country_code.matchLevel',
 '_highlightResult.office.country_code.matchedWords',
 '_highlightResult.department.value',
 '_highlightResult.department.matchLevel',
 '_highlightResult.department.matchedWords',
 '_highlightResult.profession.name.en.value',
 '_highlightResult.profession.name.en.matchLevel',
 '_highlightResult.profession.name.en.matchedWords',
 '_highlightResult.profession.category.en.value',
 '_highlightResult.profession.category.en.matchLevel',
 '_highlightResult.profession.category.en.matchedWords',
 '_highlightResult.profession.name.en.fullyHighlighted',
 '_highlightResult.department.fullyHighlighted',
 '_highlightResult.department.fullyHighlighted',
 '_highlightResult.organization.name.fullyHighlighted']

# %%
jobs.drop(axis=1, columns=col, inplace=True)
jobs.shape
# Out:
# (240, 32)

# %%
jobs
# Out:
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00
# ...                                      ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY  [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# ...                                                          ...
# HDH_w76aAlZ    [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17    [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX  [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z     [{'name': {'fr': 'Digital Marketing / Data Mar...
#
#               contract_type  experience_level_minimum             department  \
# reference
# JJ_XrAdwZp        FULL_TIME                       5.0                   None
# JJ_6687xGj        FULL_TIME                       5.0                   None
# BATCH_OLD82GY    INTERNSHIP                       0.5                  Sales
# MOONC_WaOlWMA     FULL_TIME                       2.0       Customer Service
# MOONC_ZqQNDG6     FULL_TIME                       2.0       Customer Service
# ...                     ...                       ...                    ...
# HDH_w76aAlZ      INTERNSHIP                       0.0  Direction des données
# OMC_NN7Wz17       FULL_TIME                       2.0                   None
# OPENI_1zRZkJM     FULL_TIME                       2.0     Direction Générale
# OWKIN_5GamajX     FULL_TIME                       1.0             Operations
# IA_GAwe50z       INTERNSHIP                       1.0                   None
#
#                  remote  ...       profession.name.en  \
# reference                ...
# JJ_XrAdwZp           no  ...     Business Development
# JJ_6687xGj           no  ...  IT / Project Management
# BATCH_OLD82GY   partial  ...               Operations
# MOONC_WaOlWMA        no  ...                    Other
# MOONC_ZqQNDG6        no  ...               Operations
# ...                 ...  ...                      ...
# HDH_w76aAlZ          no  ...            Data Analysis
# OMC_NN7Wz17    punctual  ...            Data Analysis
# OPENI_1zRZkJM   partial  ...            Data Analysis
# OWKIN_5GamajX   partial  ...               Operations
# IA_GAwe50z      partial  ...       Traffic Management
#
#                     profession.category.en profession_name.en.Business  \
# reference
# JJ_XrAdwZp                        Business        Business Development
# JJ_6687xGj                      Consulting                         NaN
# BATCH_OLD82GY                Support Roles                         NaN
# MOONC_WaOlWMA  Audit / Finance / Insurance                         NaN
# MOONC_ZqQNDG6                Support Roles                         NaN
# ...                                    ...                         ...
# HDH_w76aAlZ                           Tech                         NaN
# OMC_NN7Wz17                           Tech                         NaN
# OPENI_1zRZkJM                         Tech                         NaN
# OWKIN_5GamajX                Support Roles                         NaN
# IA_GAwe50z      Marketing / Communications                         NaN
#
#               _geoloc.lat _geoloc.lng profession_name.en.Consulting  \
# reference
# JJ_XrAdwZp      48.857180    2.341410                           NaN
# JJ_6687xGj      48.857180    2.341410       IT / Project Management
# BATCH_OLD82GY   48.862428    2.353970                           NaN
# MOONC_WaOlWMA   48.870122    2.318379                           NaN
# MOONC_ZqQNDG6   48.870122    2.318379                           NaN
# ...                   ...         ...                           ...
# HDH_w76aAlZ     48.835200    2.310900                           NaN
# OMC_NN7Wz17     48.861050    2.308410                           NaN
# OPENI_1zRZkJM   48.900717    2.299297                           NaN
# OWKIN_5GamajX   48.874320    2.353290                           NaN
# IA_GAwe50z      48.864089    2.343734                           NaN
#
#               profession_name.en.Support Roles  \
# reference
# JJ_XrAdwZp                                 NaN
# JJ_6687xGj                                 NaN
# BATCH_OLD82GY                       Operations
# MOONC_WaOlWMA                              NaN
# MOONC_ZqQNDG6                       Operations
# ...                                        ...
# HDH_w76aAlZ                                NaN
# OMC_NN7Wz17                                NaN
# OPENI_1zRZkJM                              NaN
# OWKIN_5GamajX                       Operations
# IA_GAwe50z                                 NaN
#
#               profession_name.en.Audit / Finance / Insurance  \
# reference
# JJ_XrAdwZp                                               NaN
# JJ_6687xGj                                               NaN
# BATCH_OLD82GY                                            NaN
# MOONC_WaOlWMA                                          Other
# MOONC_ZqQNDG6                                            NaN
# ...                                                      ...
# HDH_w76aAlZ                                              NaN
# OMC_NN7Wz17                                              NaN
# OPENI_1zRZkJM                                            NaN
# OWKIN_5GamajX                                            NaN
# IA_GAwe50z                                               NaN
#
#               profession_name.en.Tech  \
# reference
# JJ_XrAdwZp                        NaN
# JJ_6687xGj                        NaN
# BATCH_OLD82GY                     NaN
# MOONC_WaOlWMA                     NaN
# MOONC_ZqQNDG6                     NaN
# ...                               ...
# HDH_w76aAlZ             Data Analysis
# OMC_NN7Wz17             Data Analysis
# OPENI_1zRZkJM           Data Analysis
# OWKIN_5GamajX                     NaN
# IA_GAwe50z                        NaN
#
#               profession_name.en.Marketing / Communications
# reference
# JJ_XrAdwZp                                              NaN
# JJ_6687xGj                                              NaN
# BATCH_OLD82GY                                           NaN
# MOONC_WaOlWMA                                           NaN
# MOONC_ZqQNDG6                                           NaN
# ...                                                     ...
# HDH_w76aAlZ                                             NaN
# OMC_NN7Wz17                                             NaN
# OPENI_1zRZkJM                                           NaN
# OWKIN_5GamajX                                           NaN
# IA_GAwe50z                               Traffic Management
#
# [240 rows x 32 columns]

# %%
# Printing the new columns of our DataFrame
col = [c for c in jobs.columns]
col
# Out:
# ['slug',
#  'name',
#  'profile',
#  'language',
#  'published_at',
#  'sectors',
#  'contract_type',
#  'experience_level_minimum',
#  'department',
#  'remote',
#  'objectID',
#  'website.reference',
#  'organization.name',
#  'organization.reference',
#  'organization.size.en',
#  'sectors_name.en',
#  'contract_type_names.en',
#  'office.city',
#  'office.district',
#  'office.state',
#  'office.country',
#  'office.country_code',
#  'profession.name.en',
#  'profession.category.en',
#  'profession_name.en.Business',
#  '_geoloc.lat',
#  '_geoloc.lng',
#  'profession_name.en.Consulting',
#  'profession_name.en.Support Roles',
#  'profession_name.en.Audit / Finance / Insurance',
#  'profession_name.en.Tech',
#  'profession_name.en.Marketing / Communications']

# %% [markdown]
# ### Keeping only the column "profession.name.en" and droping the last columns with duplicated and redundant value for profession_name.en.(sector).

# %%
jobs.iloc[:,-10:]
# Out:
#                     profession.name.en       profession.category.en  \
# reference
# JJ_XrAdwZp        Business Development                     Business
# JJ_6687xGj     IT / Project Management                   Consulting
# BATCH_OLD82GY               Operations                Support Roles
# MOONC_WaOlWMA                    Other  Audit / Finance / Insurance
# MOONC_ZqQNDG6               Operations                Support Roles
# ...                                ...                          ...
# HDH_w76aAlZ              Data Analysis                         Tech
# OMC_NN7Wz17              Data Analysis                         Tech
# OPENI_1zRZkJM            Data Analysis                         Tech
# OWKIN_5GamajX               Operations                Support Roles
# IA_GAwe50z          Traffic Management   Marketing / Communications
#
#               profession_name.en.Business  _geoloc.lat  _geoloc.lng  \
# reference
# JJ_XrAdwZp           Business Development    48.857180     2.341410
# JJ_6687xGj                            NaN    48.857180     2.341410
# BATCH_OLD82GY                         NaN    48.862428     2.353970
# MOONC_WaOlWMA                         NaN    48.870122     2.318379
# MOONC_ZqQNDG6                         NaN    48.870122     2.318379
# ...                                   ...          ...          ...
# HDH_w76aAlZ                           NaN    48.835200     2.310900
# OMC_NN7Wz17                           NaN    48.861050     2.308410
# OPENI_1zRZkJM                         NaN    48.900717     2.299297
# OWKIN_5GamajX                         NaN    48.874320     2.353290
# IA_GAwe50z                            NaN    48.864089     2.343734
#
#               profession_name.en.Consulting profession_name.en.Support Roles  \
# reference
# JJ_XrAdwZp                              NaN                              NaN
# JJ_6687xGj          IT / Project Management                              NaN
# BATCH_OLD82GY                           NaN                       Operations
# MOONC_WaOlWMA                           NaN                              NaN
# MOONC_ZqQNDG6                           NaN                       Operations
# ...                                     ...                              ...
# HDH_w76aAlZ                             NaN                              NaN
# OMC_NN7Wz17                             NaN                              NaN
# OPENI_1zRZkJM                           NaN                              NaN
# OWKIN_5GamajX                           NaN                       Operations
# IA_GAwe50z                              NaN                              NaN
#
#               profession_name.en.Audit / Finance / Insurance  \
# reference
# JJ_XrAdwZp                                               NaN
# JJ_6687xGj                                               NaN
# BATCH_OLD82GY                                            NaN
# MOONC_WaOlWMA                                          Other
# MOONC_ZqQNDG6                                            NaN
# ...                                                      ...
# HDH_w76aAlZ                                              NaN
# OMC_NN7Wz17                                              NaN
# OPENI_1zRZkJM                                            NaN
# OWKIN_5GamajX                                            NaN
# IA_GAwe50z                                               NaN
#
#               profession_name.en.Tech  \
# reference
# JJ_XrAdwZp                        NaN
# JJ_6687xGj                        NaN
# BATCH_OLD82GY                     NaN
# MOONC_WaOlWMA                     NaN
# MOONC_ZqQNDG6                     NaN
# ...                               ...
# HDH_w76aAlZ             Data Analysis
# OMC_NN7Wz17             Data Analysis
# OPENI_1zRZkJM           Data Analysis
# OWKIN_5GamajX                     NaN
# IA_GAwe50z                        NaN
#
#               profession_name.en.Marketing / Communications
# reference
# JJ_XrAdwZp                                              NaN
# JJ_6687xGj                                              NaN
# BATCH_OLD82GY                                           NaN
# MOONC_WaOlWMA                                           NaN
# MOONC_ZqQNDG6                                           NaN
# ...                                                     ...
# HDH_w76aAlZ                                             NaN
# OMC_NN7Wz17                                             NaN
# OPENI_1zRZkJM                                           NaN
# OWKIN_5GamajX                                           NaN
# IA_GAwe50z                               Traffic Management
#
# [240 rows x 10 columns]

# %% [raw]
# col = [c for c in jobs.columns if all('profession_name.en.'.issubset(c)]
# col

# %%
col = [c for c in jobs.columns if c[:len('profession_name.en.')-1]=='profession_name.en.']

jobs.drop(columns="profession_name.en.Support Roles", inplace=True)
print(jobs.shape)
jobs
# Out:
# (240, 27)
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00
# ...                                      ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj     [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY  [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6  [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# ...                                                          ...
# HDH_w76aAlZ    [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17    [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM  [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX  [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z     [{'name': {'fr': 'Digital Marketing / Data Mar...
#
#               contract_type  experience_level_minimum             department  \
# reference
# JJ_XrAdwZp        FULL_TIME                       5.0                   None
# JJ_6687xGj        FULL_TIME                       5.0                   None
# BATCH_OLD82GY    INTERNSHIP                       0.5                  Sales
# MOONC_WaOlWMA     FULL_TIME                       2.0       Customer Service
# MOONC_ZqQNDG6     FULL_TIME                       2.0       Customer Service
# ...                     ...                       ...                    ...
# HDH_w76aAlZ      INTERNSHIP                       0.0  Direction des données
# OMC_NN7Wz17       FULL_TIME                       2.0                   None
# OPENI_1zRZkJM     FULL_TIME                       2.0     Direction Générale
# OWKIN_5GamajX     FULL_TIME                       1.0             Operations
# IA_GAwe50z       INTERNSHIP                       1.0                   None
#
#                  remote  ... office.city office.district   office.state  \
# reference                ...
# JJ_XrAdwZp           no  ...       Paris           Paris  Ile-de-France
# JJ_6687xGj           no  ...       Paris           Paris  Ile-de-France
# BATCH_OLD82GY   partial  ...       Paris           Paris  Ile-de-France
# MOONC_WaOlWMA        no  ...       Paris           Paris  Ile-de-France
# MOONC_ZqQNDG6        no  ...       Paris           Paris  Ile-de-France
# ...                 ...  ...         ...             ...            ...
# HDH_w76aAlZ          no  ...       Paris           Paris  Ile-de-France
# OMC_NN7Wz17    punctual  ...       Paris           Paris  Ile-de-France
# OPENI_1zRZkJM   partial  ...      Clichy  Hauts-de-Seine  Ile-de-France
# OWKIN_5GamajX   partial  ...       Paris           Paris  Ile-de-France
# IA_GAwe50z      partial  ...       Paris           Paris  Ile-de-France
#
#               office.country office.country_code       profession.name.en  \
# reference
# JJ_XrAdwZp            France                  FR     Business Development
# JJ_6687xGj            France                  FR  IT / Project Management
# BATCH_OLD82GY         France                  FR               Operations
# MOONC_WaOlWMA         France                  FR                    Other
# MOONC_ZqQNDG6         France                  FR               Operations
# ...                      ...                 ...                      ...
# HDH_w76aAlZ           France                  FR            Data Analysis
# OMC_NN7Wz17           France                  FR            Data Analysis
# OPENI_1zRZkJM         France                  FR            Data Analysis
# OWKIN_5GamajX         France                  FR               Operations
# IA_GAwe50z            France                  FR       Traffic Management
#
#                     profession.category.en profession_name.en.Business  \
# reference
# JJ_XrAdwZp                        Business        Business Development
# JJ_6687xGj                      Consulting                         NaN
# BATCH_OLD82GY                Support Roles                         NaN
# MOONC_WaOlWMA  Audit / Finance / Insurance                         NaN
# MOONC_ZqQNDG6                Support Roles                         NaN
# ...                                    ...                         ...
# HDH_w76aAlZ                           Tech                         NaN
# OMC_NN7Wz17                           Tech                         NaN
# OPENI_1zRZkJM                         Tech                         NaN
# OWKIN_5GamajX                Support Roles                         NaN
# IA_GAwe50z      Marketing / Communications                         NaN
#
#               _geoloc.lat _geoloc.lng
# reference
# JJ_XrAdwZp      48.857180    2.341410
# JJ_6687xGj      48.857180    2.341410
# BATCH_OLD82GY   48.862428    2.353970
# MOONC_WaOlWMA   48.870122    2.318379
# MOONC_ZqQNDG6   48.870122    2.318379
# ...                   ...         ...
# HDH_w76aAlZ     48.835200    2.310900
# OMC_NN7Wz17     48.861050    2.308410
# OPENI_1zRZkJM   48.900717    2.299297
# OWKIN_5GamajX   48.874320    2.353290
# IA_GAwe50z      48.864089    2.343734
#
# [240 rows x 27 columns]

# %%
# Printing the new columns of our DataFrame
col = [c for c in jobs.columns]
print(len(col))
print(col)
# Out:
# 27
# ['slug',
#  'name',
#  'profile',
#  'language',
#  'published_at',
#  'sectors',
#  'contract_type',
#  'experience_level_minimum',
#  'department',
#  'remote',
#  'objectID',
#  'website.reference',
#  'organization.name',
#  'organization.reference',
#  'organization.size.en',
#  'sectors_name.en',
#  'contract_type_names.en',
#  'office.city',
#  'office.district',
#  'office.state',
#  'office.country',
#  'office.country_code',
#  'profession.name.en',
#  'profession.category.en',
#  'profession_name.en.Business',
#  '_geoloc.lat',
#  '_geoloc.lng']

# %% [markdown]
# ### Droping some other useless columns:

# %%
jobs.drop(columns="website.reference", inplace=True)

# %% [markdown]
# ### Checking the intermediary result before moving to the next step of our cleaning

# %%
jobs.describe(include='all').T
# Out:
#                              count unique  \
# slug                           240    227
# name                           240    217
# profile                        227    217
# language                       240      2
# published_at                   240    240
# sectors                        240    132
# contract_type                  240      5
# experience_level_minimum     240.0    NaN
# department                     127     73
# remote                         240      4
# objectID                       240    240
# website.reference              240      1
# organization.name              240    157
# organization.reference         240    157
# organization.size.en           239      5
# sectors_name.en                240    132
# contract_type_names.en         240      5
# office.city                    240     28
# office.district                240      6
# office.state                   240      1
# office.country                 240      1
# office.country_code            240      1
# profession.name.en             240     26
# profession.category.en         240      8
# profession_name.en.Business     17      4
# _geoloc.lat                  240.0    NaN
# _geoloc.lng                  240.0    NaN
#
#                                                                            top  \
# slug                                                        data-analyst_paris
# name                                                              Data Analyst
# profile
# language                                                                    fr
# published_at                                     2021-01-14T15:56:01.175+01:00
# sectors                      [{'name': {'fr': 'E-commerce', 'en': 'E-commer...
# contract_type                                                        FULL_TIME
# experience_level_minimum                                                   NaN
# department                                                                Data
# remote                                                                      no
# objectID                                                                490668
# website.reference                                                      wttj_fr
# organization.name                                                       Deezer
# organization.reference                                                 aqRkp77
# organization.size.en                           Between 250 and 2,000 employees
# sectors_name.en                               [{'Distribution': 'E-commerce'}]
# contract_type_names.en                                               Full-Time
# office.city                                                              Paris
# office.district                                                          Paris
# office.state                                                     Ile-de-France
# office.country                                                          France
# office.country_code                                                         FR
# profession.name.en                                               Data Analysis
# profession.category.en                                                    Tech
# profession_name.en.Business                                              Sales
# _geoloc.lat                                                                NaN
# _geoloc.lng                                                                NaN
#
#                             freq       mean       std       min        25%  \
# slug                          11        NaN       NaN       NaN        NaN
# name                          13        NaN       NaN       NaN        NaN
# profile                        5        NaN       NaN       NaN        NaN
# language                     170        NaN       NaN       NaN        NaN
# published_at                   1        NaN       NaN       NaN        NaN
# sectors                        9        NaN       NaN       NaN        NaN
# contract_type                178        NaN       NaN       NaN        NaN
# experience_level_minimum     NaN   1.479167  1.777234       0.0        0.0
# department                    12        NaN       NaN       NaN        NaN
# remote                       142        NaN       NaN       NaN        NaN
# objectID                       1        NaN       NaN       NaN        NaN
# website.reference            240        NaN       NaN       NaN        NaN
# organization.name              7        NaN       NaN       NaN        NaN
# organization.reference         7        NaN       NaN       NaN        NaN
# organization.size.en          81        NaN       NaN       NaN        NaN
# sectors_name.en                9        NaN       NaN       NaN        NaN
# contract_type_names.en       178        NaN       NaN       NaN        NaN
# office.city                  188        NaN       NaN       NaN        NaN
# office.district              191        NaN       NaN       NaN        NaN
# office.state                 240        NaN       NaN       NaN        NaN
# office.country               240        NaN       NaN       NaN        NaN
# office.country_code          240        NaN       NaN       NaN        NaN
# profession.name.en           111        NaN       NaN       NaN        NaN
# profession.category.en       151        NaN       NaN       NaN        NaN
# profession_name.en.Business    5        NaN       NaN       NaN        NaN
# _geoloc.lat                  NaN  48.869517  0.025509   48.7492  48.864089
# _geoloc.lng                  NaN   2.324565   0.04601  2.173517   2.301777
#
#                                    50%        75%        max
# slug                               NaN        NaN        NaN
# name                               NaN        NaN        NaN
# profile                            NaN        NaN        NaN
# language                           NaN        NaN        NaN
# published_at                       NaN        NaN        NaN
# sectors                            NaN        NaN        NaN
# contract_type                      NaN        NaN        NaN
# experience_level_minimum          0.75        3.0       10.0
# department                         NaN        NaN        NaN
# remote                             NaN        NaN        NaN
# objectID                           NaN        NaN        NaN
# website.reference                  NaN        NaN        NaN
# organization.name                  NaN        NaN        NaN
# organization.reference             NaN        NaN        NaN
# organization.size.en               NaN        NaN        NaN
# sectors_name.en                    NaN        NaN        NaN
# contract_type_names.en             NaN        NaN        NaN
# office.city                        NaN        NaN        NaN
# office.district                    NaN        NaN        NaN
# office.state                       NaN        NaN        NaN
# office.country                     NaN        NaN        NaN
# office.country_code                NaN        NaN        NaN
# profession.name.en                 NaN        NaN        NaN
# profession.category.en             NaN        NaN        NaN
# profession_name.en.Business        NaN        NaN        NaN
# _geoloc.lat                  48.872279  48.882571  48.967775
# _geoloc.lng                   2.334106   2.350552   2.547917

# %% [markdown]
# ## Cleaning values

# %% [markdown]
# #### Sectors: unpacking values

# %%
print(jobs["sectors"])
print(jobs["sectors"][0])
print(jobs["sectors"][0][0])
print(jobs["sectors"][0][0]["name"])
print(jobs["sectors"][0][0]["name"]["en"])
# Out:
# reference
# JJ_XrAdwZp       [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# JJ_6687xGj       [{'name': {'fr': 'Santé', 'en': 'Health', 'es'...
# BATCH_OLD82GY    [{'name': {'fr': 'Application mobile', 'en': '...
# MOONC_WaOlWMA    [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
# MOONC_ZqQNDG6    [{'name': {'fr': 'Banque', 'en': 'Banking', 'e...
#                                        ...
# HDH_w76aAlZ      [{'name': {'fr': 'Intelligence artificielle / ...
# OMC_NN7Wz17      [{'name': {'fr': 'Luxe', 'en': 'Luxury', 'es':...
# OPENI_1zRZkJM    [{'name': {'fr': 'IT / Digital', 'en': 'IT / D...
# OWKIN_5GamajX    [{'name': {'fr': 'Intelligence artificielle / ...
# IA_GAwe50z       [{'name': {'fr': 'Digital Marketing / Data Mar...
# Name: sectors, Length: 240, dtype: object
# [{'name': {'fr': 'Santé', 'en': 'Health', 'es': 'Salud', 'cs': 'Zdraví', 'sk': 'Zdravie'}, 'parent': {'fr': 'Santé / Social / Environnement', 'en': 'Health / Social / Environment', 'es': 'Salud/Social/Medio Ambiente', 'cs': 'Zdraví / Sociální sektor / Životní prostředí', 'sk': 'Zdravie / Sociálna oblasť / Životné prostredie'}}]
# {'name': {'fr': 'Santé', 'en': 'Health', 'es': 'Salud', 'cs': 'Zdraví', 'sk': 'Zdravie'}, 'parent': {'fr': 'Santé / Social / Environnement', 'en': 'Health / Social / Environment', 'es': 'Salud/Social/Medio Ambiente', 'cs': 'Zdraví / Sociální sektor / Životní prostředí', 'sk': 'Zdravie / Sociálna oblasť / Životné prostredie'}}
# {'fr': 'Santé', 'en': 'Health', 'es': 'Salud', 'cs': 'Zdraví', 'sk': 'Zdravie'}
# Health

# %% [markdown]
# As we can see, the list may have one or more sectors for each job/company.
#
# Also, it may have one parent sector or more for each.
#
# Both informations interest me, so I will unpack them in 2 different columns.

# %%
jobs_sectors = pd.DataFrame()

# Identifying the sectors for each line and aggregating them in a list:
sectors_list=list(" "*len(jobs["sectors"]))
for index, i in enumerate(jobs["sectors"]):
    for j in i:
        if sectors_list[index] == " ":
            sectors_list[index] = (j["name"]["en"])
        else:
            sectors_list[index] += " / " + (j["name"]["en"])

# Storing in a dataframe, to test first.
jobs_sectors["sectors"] = [i for i in sectors_list]

# Identifying the parent sectors for each line and aggregating them in a list:
parents_list=list(" "*len(jobs["sectors"]))
for index, i in enumerate(jobs["sectors"]):
    for j in i:
        if parents_list[index] == " ":
            parents_list[index] = (j["parent"]["en"])
        elif j["parent"]["en"] in parents_list[index]:
            pass
        else:
            parents_list[index] += " / " + (j["parent"]["en"])

# Storing in a dataframe, to test first.
jobs_sectors["sectors_parents"] = [i for i in parents_list]

# Setting index to match the jobs dataframe
jobs_sectors.set_index(jobs.index, inplace=True)

# Printing the dataframe to see if everything is alright 
jobs_sectors
# Out:
#                                                          sectors  \
# reference
# JJ_XrAdwZp                                                Health
# JJ_6687xGj                                                Health
# BATCH_OLD82GY  Mobile Apps / SaaS / Cloud Services / AdTech /...
# MOONC_WaOlWMA                  Banking / IT / Digital / Big Data
# MOONC_ZqQNDG6                  Banking / IT / Digital / Big Data
# ...                                                          ...
# HDH_w76aAlZ    Artificial Intelligence / Machine Learning / H...
# OMC_NN7Wz17                         Luxury / Fashion / Cosmetics
# OPENI_1zRZkJM    IT / Digital / Electronics / Telecommunications
# OWKIN_5GamajX  Artificial Intelligence / Machine Learning / B...
# IA_GAwe50z     Digital Marketing / Data Marketing / Digital /...
#
#                                                  sectors_parents
# reference
# JJ_XrAdwZp                         Health / Social / Environment
# JJ_6687xGj                         Health / Social / Environment
# BATCH_OLD82GY            Tech / Advertising / Marketing / Agency
# MOONC_WaOlWMA  Banking / Insurance / Finance / Consulting / A...
# MOONC_ZqQNDG6  Banking / Insurance / Finance / Consulting / A...
# ...                                                          ...
# HDH_w76aAlZ                 Tech / Health / Social / Environment
# OMC_NN7Wz17                Fashion / Luxury / Beauty / Lifestyle
# OPENI_1zRZkJM                      Consulting / Audit / Industry
# OWKIN_5GamajX               Tech / Health / Social / Environment
# IA_GAwe50z     Consulting / Audit / Advertising / Marketing /...
#
# [240 rows x 2 columns]

# %%
# Modifying in the dataframe - droping the previous "sectors" column and adding the 2 new columns:
jobs.drop(columns="sectors", inplace=True)
jobs.drop(columns="sectors_name.en", inplace=True)
jobs = pd.concat([jobs,jobs_sectors], axis=1)
jobs
# Out:
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at contract_type  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00     FULL_TIME
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00     FULL_TIME
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00    INTERNSHIP
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00     FULL_TIME
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00     FULL_TIME
# ...                                      ...           ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00    INTERNSHIP
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00     FULL_TIME
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00     FULL_TIME
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00     FULL_TIME
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00    INTERNSHIP
#
#                experience_level_minimum             department    remote  \
# reference
# JJ_XrAdwZp                          5.0                   None        no
# JJ_6687xGj                          5.0                   None        no
# BATCH_OLD82GY                       0.5                  Sales   partial
# MOONC_WaOlWMA                       2.0       Customer Service        no
# MOONC_ZqQNDG6                       2.0       Customer Service        no
# ...                                 ...                    ...       ...
# HDH_w76aAlZ                         0.0  Direction des données        no
# OMC_NN7Wz17                         2.0                   None  punctual
# OPENI_1zRZkJM                       2.0     Direction Générale   partial
# OWKIN_5GamajX                       1.0             Operations   partial
# IA_GAwe50z                          1.0                   None   partial
#
#               objectID  ...   office.state office.country office.country_code  \
# reference               ...
# JJ_XrAdwZp      494233  ...  Ile-de-France         France                  FR
# JJ_6687xGj      494186  ...  Ile-de-France         France                  FR
# BATCH_OLD82GY   490169  ...  Ile-de-France         France                  FR
# MOONC_WaOlWMA   493447  ...  Ile-de-France         France                  FR
# MOONC_ZqQNDG6   492944  ...  Ile-de-France         France                  FR
# ...                ...  ...            ...            ...                 ...
# HDH_w76aAlZ     463502  ...  Ile-de-France         France                  FR
# OMC_NN7Wz17     463339  ...  Ile-de-France         France                  FR
# OPENI_1zRZkJM   423932  ...  Ile-de-France         France                  FR
# OWKIN_5GamajX   462834  ...  Ile-de-France         France                  FR
# IA_GAwe50z      462485  ...  Ile-de-France         France                  FR
#
#                     profession.name.en       profession.category.en  \
# reference
# JJ_XrAdwZp        Business Development                     Business
# JJ_6687xGj     IT / Project Management                   Consulting
# BATCH_OLD82GY               Operations                Support Roles
# MOONC_WaOlWMA                    Other  Audit / Finance / Insurance
# MOONC_ZqQNDG6               Operations                Support Roles
# ...                                ...                          ...
# HDH_w76aAlZ              Data Analysis                         Tech
# OMC_NN7Wz17              Data Analysis                         Tech
# OPENI_1zRZkJM            Data Analysis                         Tech
# OWKIN_5GamajX               Operations                Support Roles
# IA_GAwe50z          Traffic Management   Marketing / Communications
#
#               profession_name.en.Business _geoloc.lat _geoloc.lng  \
# reference
# JJ_XrAdwZp           Business Development   48.857180    2.341410
# JJ_6687xGj                            NaN   48.857180    2.341410
# BATCH_OLD82GY                         NaN   48.862428    2.353970
# MOONC_WaOlWMA                         NaN   48.870122    2.318379
# MOONC_ZqQNDG6                         NaN   48.870122    2.318379
# ...                                   ...         ...         ...
# HDH_w76aAlZ                           NaN   48.835200    2.310900
# OMC_NN7Wz17                           NaN   48.861050    2.308410
# OPENI_1zRZkJM                         NaN   48.900717    2.299297
# OWKIN_5GamajX                         NaN   48.874320    2.353290
# IA_GAwe50z                            NaN   48.864089    2.343734
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp                                                Health
# JJ_6687xGj                                                Health
# BATCH_OLD82GY  Mobile Apps / SaaS / Cloud Services / AdTech /...
# MOONC_WaOlWMA                  Banking / IT / Digital / Big Data
# MOONC_ZqQNDG6                  Banking / IT / Digital / Big Data
# ...                                                          ...
# HDH_w76aAlZ    Artificial Intelligence / Machine Learning / H...
# OMC_NN7Wz17                         Luxury / Fashion / Cosmetics
# OPENI_1zRZkJM    IT / Digital / Electronics / Telecommunications
# OWKIN_5GamajX  Artificial Intelligence / Machine Learning / B...
# IA_GAwe50z     Digital Marketing / Data Marketing / Digital /...
#
#                                                  sectors_parents
# reference
# JJ_XrAdwZp                         Health / Social / Environment
# JJ_6687xGj                         Health / Social / Environment
# BATCH_OLD82GY            Tech / Advertising / Marketing / Agency
# MOONC_WaOlWMA  Banking / Insurance / Finance / Consulting / A...
# MOONC_ZqQNDG6  Banking / Insurance / Finance / Consulting / A...
# ...                                                          ...
# HDH_w76aAlZ                 Tech / Health / Social / Environment
# OMC_NN7Wz17                Fashion / Luxury / Beauty / Lifestyle
# OPENI_1zRZkJM                      Consulting / Audit / Industry
# OWKIN_5GamajX               Tech / Health / Social / Environment
# IA_GAwe50z     Consulting / Audit / Advertising / Marketing /...
#
# [240 rows x 28 columns]

# %% [markdown]
# ### Profile cleaning

# %%
profile = jobs["profile"]
profile
# Out:
# reference
# JJ_XrAdwZp       * Bachelor’s degree in Information Technology,...
# JJ_6687xGj       * Bachelor’s degree in Information Technology,...
# BATCH_OLD82GY    - À la recherche d'une alternance ou d’un stag...
# MOONC_WaOlWMA    Bac +3/+5 en Banque/ Conformité\r\nVous avez d...
# MOONC_ZqQNDG6    Bac +3/+5 en Banque/ Conformité\r\nVous avez d...
#                                        ...
# HDH_w76aAlZ      **Compétences techniques**\r\n▪ Linux/Bash\r\n...
# OMC_NN7Wz17      Vous êtes passionné(e) par les données, agile,...
# OPENI_1zRZkJM    Profil\r\n\r\nVos compétences :\r\n•\tCompéten...
# OWKIN_5GamajX    **About you**\r\n\r\n* You are fluent and have...
# IA_GAwe50z       - Analytique/ Data-driven : Vous aimez manipul...
# Name: profile, Length: 240, dtype: object

# %%
from bs4 import BeautifulSoup
from markdown import markdown
import re

def markdown_to_text(markdown_string):
    """ Converts a markdown string to plaintext """

    # md -> html -> text since BeautifulSoup can extract text cleanly
    html = markdown(markdown_string)

    # remove code snippets
    html = re.sub(r'<pre>(.*?)</pre>', ' ', html)
    html = re.sub(r'<code>(.*?)</code >', ' ', html)

    # extract text
    soup = BeautifulSoup(html, "html.parser")
    text = ''.join(soup.findAll(text=True))

    return text

# %%
profile.fillna('').apply(markdown_to_text)
# Out:
# reference
# JJ_XrAdwZp       \nBachelor’s degree in Information Technology,...
# JJ_6687xGj       \nBachelor’s degree in Information Technology,...
# BATCH_OLD82GY    \nÀ la recherche d'une alternance ou d’un stag...
# MOONC_WaOlWMA    Bac +3/+5 en Banque/ Conformité\nVous avez déj...
# MOONC_ZqQNDG6    Bac +3/+5 en Banque/ Conformité\nVous avez déj...
#                                        ...
# HDH_w76aAlZ      Compétences techniques\n▪ Linux/Bash\n▪ Connai...
# OMC_NN7Wz17      Vous êtes passionné(e) par les données, agile,...
# OPENI_1zRZkJM    Profil\nVos compétences :\n•   Compétences ava...
# OWKIN_5GamajX    About you\n\nYou are fluent and have excellent...
# IA_GAwe50z       \n\nAnalytique/ Data-driven : Vous aimez manip...
# Name: profile, Length: 240, dtype: object

# %%
# Checking the result of my test
print(profile[0])
# Out:
# * Bachelor’s degree in Information Technology, Computer Science, Economics or other related field. Professional certifications are a plus, especially in SAP SD, Project Management and ITIL.
# * Solid grasp of OTC processes, and Supply Chain processes in general.
# * At least 5 years of IT experience in a corporate environment supporting SAP projects required, with hands-on functional configuration experience with SAP-SD.
# * Consistent record in IT project management and leading small team prefered. Knowledge of PMx framework.
# * Detailed knowledge of SAP SD integration with MM and FICO.
# * Experience with interfaces, IDOCs, ABAP and/or SAP authorizations a plus. Ability to debug ABAP code.
# * Experience in SD requirements capturing; customer interaction, detailed documentation of requirements and functional specifications, creation of process and data flows.
# * Ability to work in a virtual setup (combination of on-shore and offshore), including diverse groups of people with varied backgrounds and cultural experiences.
# * Strong collaboration and team building skills.
# * Strong analytical skills and problem-solving skills.
# * Good people skills and a proficient knowledge of English language.
# * Strongly result driven, quick learner, self-starter, work independently.
# * Strong planning and tracking skills. Realistic planning and delivery according to plan.
# * High sense of compliance. Solid knowledge of formal Change Management and System Development Life Cycle methodologies. Knowledge of SOX compliance and/or GMP validation is a plus.
# * Knowledge of MS office tools is a must.
# * Experience with JIRA and XRAY.
# * Ability to travel 20 – 30% of the time.
#
# Please submit your CV in English language.
#
# What’s in it for you…?
#
# “Caring for the world, one person at a time…”
#
# As an employee, we consider you as our most valuable asset. We take your career seriously. As part of a global team in an innovative environment, your development is key and our day-to-day responsibility. Through e-university, on job training, various projects, and programs, we ensure your personal growth. Our benefits ensure we care for you and your family now and in the future! We are an equal opportunity employer and value diversity at our company. We do not discriminate on the basis of race, religion, color, national origin, gender, sexual orientation, age, marital status, or disability status.

# %%
# Adopting the result
jobs["profile"] = profile

# %%
jobs
# Out:
#                                                             slug  \
# reference
# JJ_XrAdwZp               lead-business-analyst-deliver-erp_paris
# JJ_6687xGj               lead-business-analyst-finance-erp_paris
# BATCH_OLD82GY  junior-business-operations-manager-stage-alter...
# MOONC_WaOlWMA            analyste-conformite_paris_MOONC_WaOlWMA
# MOONC_ZqQNDG6                          analyste-conformite_paris
# ...                                                          ...
# HDH_w76aAlZ    stage-developpeur-euse-organisation-de-data-ch...
# OMC_NN7Wz17                               business-analyst_paris
# OPENI_1zRZkJM        business-operations-data-analyst-h-f_clichy
# OWKIN_5GamajX                       operations-analyst-h-f_paris
# IA_GAwe50z                    traffic-manager-pre-embauche_paris
#
#                                                             name  \
# reference
# JJ_XrAdwZp                    Lead, Business Analyst Deliver ERP
# JJ_6687xGj                    Lead, Business Analyst Finance ERP
# BATCH_OLD82GY      Junior Business Operations [stage/alternance]
# MOONC_WaOlWMA                                Analyste Conformité
# MOONC_ZqQNDG6                                Analyste Conformité
# ...                                                          ...
# HDH_w76aAlZ    Stage -Développeur(euse) - organisation de Dat...
# OMC_NN7Wz17                                     Business Analyst
# OPENI_1zRZkJM             Business Operations Data Analyst (H/F)
# OWKIN_5GamajX                           Operations Analyst (H/F)
# IA_GAwe50z                    Acquisition Manager (Pré-embauche)
#
#                                                          profile language  \
# reference
# JJ_XrAdwZp     * Bachelor’s degree in Information Technology,...       fr
# JJ_6687xGj     * Bachelor’s degree in Information Technology,...       fr
# BATCH_OLD82GY  - À la recherche d'une alternance ou d’un stag...       fr
# MOONC_WaOlWMA  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# MOONC_ZqQNDG6  Bac +3/+5 en Banque/ Conformité\r\nVous avez d...       fr
# ...                                                          ...      ...
# HDH_w76aAlZ    **Compétences techniques**\r\n▪ Linux/Bash\r\n...       fr
# OMC_NN7Wz17    Vous êtes passionné(e) par les données, agile,...       fr
# OPENI_1zRZkJM  Profil\r\n\r\nVos compétences :\r\n•\tCompéten...       fr
# OWKIN_5GamajX  **About you**\r\n\r\n* You are fluent and have...       en
# IA_GAwe50z     - Analytique/ Data-driven : Vous aimez manipul...       fr
#
#                                 published_at contract_type  \
# reference
# JJ_XrAdwZp     2021-02-19T12:57:57.889+01:00     FULL_TIME
# JJ_6687xGj     2021-02-19T12:38:23.555+01:00     FULL_TIME
# BATCH_OLD82GY  2021-02-19T11:13:59.409+01:00    INTERNSHIP
# MOONC_WaOlWMA  2021-02-19T11:10:28.820+01:00     FULL_TIME
# MOONC_ZqQNDG6  2021-02-19T11:10:18.292+01:00     FULL_TIME
# ...                                      ...           ...
# HDH_w76aAlZ    2021-01-14T09:29:50.986+01:00    INTERNSHIP
# OMC_NN7Wz17    2021-01-13T22:15:10.808+01:00     FULL_TIME
# OPENI_1zRZkJM  2021-01-13T18:28:20.780+01:00     FULL_TIME
# OWKIN_5GamajX  2021-01-13T11:01:21.271+01:00     FULL_TIME
# IA_GAwe50z     2021-01-12T18:08:16.849+01:00    INTERNSHIP
#
#                experience_level_minimum             department    remote  \
# reference
# JJ_XrAdwZp                          5.0                   None        no
# JJ_6687xGj                          5.0                   None        no
# BATCH_OLD82GY                       0.5                  Sales   partial
# MOONC_WaOlWMA                       2.0       Customer Service        no
# MOONC_ZqQNDG6                       2.0       Customer Service        no
# ...                                 ...                    ...       ...
# HDH_w76aAlZ                         0.0  Direction des données        no
# OMC_NN7Wz17                         2.0                   None  punctual
# OPENI_1zRZkJM                       2.0     Direction Générale   partial
# OWKIN_5GamajX                       1.0             Operations   partial
# IA_GAwe50z                          1.0                   None   partial
#
#               objectID  ...   office.state office.country office.country_code  \
# reference               ...
# JJ_XrAdwZp      494233  ...  Ile-de-France         France                  FR
# JJ_6687xGj      494186  ...  Ile-de-France         France                  FR
# BATCH_OLD82GY   490169  ...  Ile-de-France         France                  FR
# MOONC_WaOlWMA   493447  ...  Ile-de-France         France                  FR
# MOONC_ZqQNDG6   492944  ...  Ile-de-France         France                  FR
# ...                ...  ...            ...            ...                 ...
# HDH_w76aAlZ     463502  ...  Ile-de-France         France                  FR
# OMC_NN7Wz17     463339  ...  Ile-de-France         France                  FR
# OPENI_1zRZkJM   423932  ...  Ile-de-France         France                  FR
# OWKIN_5GamajX   462834  ...  Ile-de-France         France                  FR
# IA_GAwe50z      462485  ...  Ile-de-France         France                  FR
#
#                     profession.name.en       profession.category.en  \
# reference
# JJ_XrAdwZp        Business Development                     Business
# JJ_6687xGj     IT / Project Management                   Consulting
# BATCH_OLD82GY               Operations                Support Roles
# MOONC_WaOlWMA                    Other  Audit / Finance / Insurance
# MOONC_ZqQNDG6               Operations                Support Roles
# ...                                ...                          ...
# HDH_w76aAlZ              Data Analysis                         Tech
# OMC_NN7Wz17              Data Analysis                         Tech
# OPENI_1zRZkJM            Data Analysis                         Tech
# OWKIN_5GamajX               Operations                Support Roles
# IA_GAwe50z          Traffic Management   Marketing / Communications
#
#               profession_name.en.Business _geoloc.lat _geoloc.lng  \
# reference
# JJ_XrAdwZp           Business Development   48.857180    2.341410
# JJ_6687xGj                            NaN   48.857180    2.341410
# BATCH_OLD82GY                         NaN   48.862428    2.353970
# MOONC_WaOlWMA                         NaN   48.870122    2.318379
# MOONC_ZqQNDG6                         NaN   48.870122    2.318379
# ...                                   ...         ...         ...
# HDH_w76aAlZ                           NaN   48.835200    2.310900
# OMC_NN7Wz17                           NaN   48.861050    2.308410
# OPENI_1zRZkJM                         NaN   48.900717    2.299297
# OWKIN_5GamajX                         NaN   48.874320    2.353290
# IA_GAwe50z                            NaN   48.864089    2.343734
#
#                                                          sectors  \
# reference
# JJ_XrAdwZp                                                Health
# JJ_6687xGj                                                Health
# BATCH_OLD82GY  Mobile Apps / SaaS / Cloud Services / AdTech /...
# MOONC_WaOlWMA                  Banking / IT / Digital / Big Data
# MOONC_ZqQNDG6                  Banking / IT / Digital / Big Data
# ...                                                          ...
# HDH_w76aAlZ    Artificial Intelligence / Machine Learning / H...
# OMC_NN7Wz17                         Luxury / Fashion / Cosmetics
# OPENI_1zRZkJM    IT / Digital / Electronics / Telecommunications
# OWKIN_5GamajX  Artificial Intelligence / Machine Learning / B...
# IA_GAwe50z     Digital Marketing / Data Marketing / Digital /...
#
#                                                  sectors_parents
# reference
# JJ_XrAdwZp                         Health / Social / Environment
# JJ_6687xGj                         Health / Social / Environment
# BATCH_OLD82GY            Tech / Advertising / Marketing / Agency
# MOONC_WaOlWMA  Banking / Insurance / Finance / Consulting / A...
# MOONC_ZqQNDG6  Banking / Insurance / Finance / Consulting / A...
# ...                                                          ...
# HDH_w76aAlZ                 Tech / Health / Social / Environment
# OMC_NN7Wz17                Fashion / Luxury / Beauty / Lifestyle
# OPENI_1zRZkJM                      Consulting / Audit / Industry
# OWKIN_5GamajX               Tech / Health / Social / Environment
# IA_GAwe50z     Consulting / Audit / Advertising / Marketing /...
#
# [240 rows x 28 columns]

# %% [markdown]
# ## Type of columns

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, JJ_XrAdwZp to IA_GAwe50z
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   slug                         240 non-null    object
#  1   name                         240 non-null    object
#  2   profile                      227 non-null    object
#  3   language                     240 non-null    object
#  4   published_at                 240 non-null    object
#  5   contract_type                240 non-null    object
#  6   experience_level_minimum     240 non-null    float64
#  7   department                   127 non-null    object
#  8   remote                       240 non-null    object
#  9   objectID                     240 non-null    object
#  10  website.reference            240 non-null    object
#  11  organization.name            240 non-null    object
#  12  organization.reference       240 non-null    object
#  13  organization.size.en         239 non-null    object
#  14  sectors_name.en              240 non-null    object
#  15  contract_type_names.en       240 non-null    object
#  16  office.city                  240 non-null    object
#  17  office.district              240 non-null    object
#  18  office.state                 240 non-null    object
#  19  office.country               240 non-null    object
#  20  office.country_code          240 non-null    object
#  21  profession.name.en           240 non-null    object
#  22  profession.category.en       240 non-null    object
#  23  profession_name.en.Business  17 non-null     object
#  24  _geoloc.lat                  240 non-null    float64
#  25  _geoloc.lng                  240 non-null    float64
#  26  sectors                      240 non-null    object
#  27  sectors_parents              240 non-null    object
# dtypes: float64(3), object(25)
# memory usage: 62.5+ KB

# %%
jobs["published_at"] = jobs["published_at"].astype("datetime64")
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, JJ_XrAdwZp to IA_GAwe50z
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   slug                         240 non-null    object
#  1   name                         240 non-null    object
#  2   profile                      227 non-null    object
#  3   language                     240 non-null    object
#  4   published_at                 240 non-null    datetime64[ns]
#  5   contract_type                240 non-null    object
#  6   experience_level_minimum     240 non-null    float64
#  7   department                   127 non-null    object
#  8   remote                       240 non-null    object
#  9   objectID                     240 non-null    object
#  10  website.reference            240 non-null    object
#  11  organization.name            240 non-null    object
#  12  organization.reference       240 non-null    object
#  13  organization.size.en         239 non-null    object
#  14  sectors_name.en              240 non-null    object
#  15  contract_type_names.en       240 non-null    object
#  16  office.city                  240 non-null    object
#  17  office.district              240 non-null    object
#  18  office.state                 240 non-null    object
#  19  office.country               240 non-null    object
#  20  office.country_code          240 non-null    object
#  21  profession.name.en           240 non-null    object
#  22  profession.category.en       240 non-null    object
#  23  profession_name.en.Business  17 non-null     object
#  24  _geoloc.lat                  240 non-null    float64
#  25  _geoloc.lng                  240 non-null    float64
#  26  sectors                      240 non-null    object
#  27  sectors_parents              240 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(24)
# memory usage: 62.5+ KB

# %%
jobs.describe(include="all",datetime_is_numeric=True)
# Out:
#                       slug          name profile language  \
# count                  240           240     227      240
# unique                 227           217     217        2
# top     data-analyst_paris  Data Analyst               fr
# freq                    11            13       5      170
# mean                   NaN           NaN     NaN      NaN
# min                    NaN           NaN     NaN      NaN
# 25%                    NaN           NaN     NaN      NaN
# 50%                    NaN           NaN     NaN      NaN
# 75%                    NaN           NaN     NaN      NaN
# max                    NaN           NaN     NaN      NaN
# std                    NaN           NaN     NaN      NaN
#
#                          published_at contract_type  experience_level_minimum  \
# count                             240           240                240.000000
# unique                            NaN             5                       NaN
# top                               NaN     FULL_TIME                       NaN
# freq                              NaN           178                       NaN
# mean    2021-02-06 01:33:48.855312384           NaN                  1.479167
# min        2021-01-12 17:08:16.849000           NaN                  0.000000
# 25%     2021-01-28 10:27:26.335749888           NaN                  0.000000
# 50%     2021-02-08 16:20:10.178500096           NaN                  0.750000
# 75%     2021-02-15 22:09:20.345250048           NaN                  3.000000
# max        2021-02-19 11:57:57.889000           NaN                 10.000000
# std                               NaN           NaN                  1.777234
#
#        department remote objectID  ...   office.state office.country  \
# count         127    240      240  ...            240            240
# unique         73      4      240  ...              1              1
# top          Data     no   490668  ...  Ile-de-France         France
# freq           12    142        1  ...            240            240
# mean          NaN    NaN      NaN  ...            NaN            NaN
# min           NaN    NaN      NaN  ...            NaN            NaN
# 25%           NaN    NaN      NaN  ...            NaN            NaN
# 50%           NaN    NaN      NaN  ...            NaN            NaN
# 75%           NaN    NaN      NaN  ...            NaN            NaN
# max           NaN    NaN      NaN  ...            NaN            NaN
# std           NaN    NaN      NaN  ...            NaN            NaN
#
#        office.country_code profession.name.en profession.category.en  \
# count                  240                240                    240
# unique                   1                 26                      8
# top                     FR      Data Analysis                   Tech
# freq                   240                111                    151
# mean                   NaN                NaN                    NaN
# min                    NaN                NaN                    NaN
# 25%                    NaN                NaN                    NaN
# 50%                    NaN                NaN                    NaN
# 75%                    NaN                NaN                    NaN
# max                    NaN                NaN                    NaN
# std                    NaN                NaN                    NaN
#
#        profession_name.en.Business _geoloc.lat _geoloc.lng     sectors  \
# count                           17  240.000000  240.000000         240
# unique                           4         NaN         NaN         132
# top                          Sales         NaN         NaN  E-commerce
# freq                             5         NaN         NaN           9
# mean                           NaN   48.869517    2.324565         NaN
# min                            NaN   48.749200    2.173517         NaN
# 25%                            NaN   48.864089    2.301777         NaN
# 50%                            NaN   48.872279    2.334106         NaN
# 75%                            NaN   48.882571    2.350552         NaN
# max                            NaN   48.967775    2.547917         NaN
# std                            NaN    0.025509    0.046010         NaN
#
#        sectors_parents
# count              240
# unique              70
# top               Tech
# freq                21
# mean               NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN
# std                NaN
#
# [11 rows x 28 columns]

# %%
jobs.describe(include="all",datetime_is_numeric=True).T
# Out:
#                              count unique                               top  \
# slug                           240    227                data-analyst_paris
# name                           240    217                      Data Analyst
# profile                        227    217
# language                       240      2                                fr
# published_at                   240    NaN                               NaN
# contract_type                  240      5                         FULL_TIME
# experience_level_minimum     240.0    NaN                               NaN
# department                     127     73                              Data
# remote                         240      4                                no
# objectID                       240    240                            490668
# website.reference              240      1                           wttj_fr
# organization.name              240    157                            Deezer
# organization.reference         240    157                           aqRkp77
# organization.size.en           239      5   Between 250 and 2,000 employees
# sectors_name.en                240    132  [{'Distribution': 'E-commerce'}]
# contract_type_names.en         240      5                         Full-Time
# office.city                    240     28                             Paris
# office.district                240      6                             Paris
# office.state                   240      1                     Ile-de-France
# office.country                 240      1                            France
# office.country_code            240      1                                FR
# profession.name.en             240     26                     Data Analysis
# profession.category.en         240      8                              Tech
# profession_name.en.Business     17      4                             Sales
# _geoloc.lat                  240.0    NaN                               NaN
# _geoloc.lng                  240.0    NaN                               NaN
# sectors                        240    132                        E-commerce
# sectors_parents                240     70                              Tech
#
#                             freq                           mean  \
# slug                          11                            NaN
# name                          13                            NaN
# profile                        5                            NaN
# language                     170                            NaN
# published_at                 NaN  2021-02-06 01:33:48.855312384
# contract_type                178                            NaN
# experience_level_minimum     NaN                       1.479167
# department                    12                            NaN
# remote                       142                            NaN
# objectID                       1                            NaN
# website.reference            240                            NaN
# organization.name              7                            NaN
# organization.reference         7                            NaN
# organization.size.en          81                            NaN
# sectors_name.en                9                            NaN
# contract_type_names.en       178                            NaN
# office.city                  188                            NaN
# office.district              191                            NaN
# office.state                 240                            NaN
# office.country               240                            NaN
# office.country_code          240                            NaN
# profession.name.en           111                            NaN
# profession.category.en       151                            NaN
# profession_name.en.Business    5                            NaN
# _geoloc.lat                  NaN                      48.869517
# _geoloc.lng                  NaN                       2.324565
# sectors                        9                            NaN
# sectors_parents               21                            NaN
#
#                                                     min  \
# slug                                                NaN
# name                                                NaN
# profile                                             NaN
# language                                            NaN
# published_at                 2021-01-12 17:08:16.849000
# contract_type                                       NaN
# experience_level_minimum                            0.0
# department                                          NaN
# remote                                              NaN
# objectID                                            NaN
# website.reference                                   NaN
# organization.name                                   NaN
# organization.reference                              NaN
# organization.size.en                                NaN
# sectors_name.en                                     NaN
# contract_type_names.en                              NaN
# office.city                                         NaN
# office.district                                     NaN
# office.state                                        NaN
# office.country                                      NaN
# office.country_code                                 NaN
# profession.name.en                                  NaN
# profession.category.en                              NaN
# profession_name.en.Business                         NaN
# _geoloc.lat                                     48.7492
# _geoloc.lng                                    2.173517
# sectors                                             NaN
# sectors_parents                                     NaN
#
#                                                        25%  \
# slug                                                   NaN
# name                                                   NaN
# profile                                                NaN
# language                                               NaN
# published_at                 2021-01-28 10:27:26.335749888
# contract_type                                          NaN
# experience_level_minimum                               0.0
# department                                             NaN
# remote                                                 NaN
# objectID                                               NaN
# website.reference                                      NaN
# organization.name                                      NaN
# organization.reference                                 NaN
# organization.size.en                                   NaN
# sectors_name.en                                        NaN
# contract_type_names.en                                 NaN
# office.city                                            NaN
# office.district                                        NaN
# office.state                                           NaN
# office.country                                         NaN
# office.country_code                                    NaN
# profession.name.en                                     NaN
# profession.category.en                                 NaN
# profession_name.en.Business                            NaN
# _geoloc.lat                                      48.864089
# _geoloc.lng                                       2.301777
# sectors                                                NaN
# sectors_parents                                        NaN
#
#                                                        50%  \
# slug                                                   NaN
# name                                                   NaN
# profile                                                NaN
# language                                               NaN
# published_at                 2021-02-08 16:20:10.178500096
# contract_type                                          NaN
# experience_level_minimum                              0.75
# department                                             NaN
# remote                                                 NaN
# objectID                                               NaN
# website.reference                                      NaN
# organization.name                                      NaN
# organization.reference                                 NaN
# organization.size.en                                   NaN
# sectors_name.en                                        NaN
# contract_type_names.en                                 NaN
# office.city                                            NaN
# office.district                                        NaN
# office.state                                           NaN
# office.country                                         NaN
# office.country_code                                    NaN
# profession.name.en                                     NaN
# profession.category.en                                 NaN
# profession_name.en.Business                            NaN
# _geoloc.lat                                      48.872279
# _geoloc.lng                                       2.334106
# sectors                                                NaN
# sectors_parents                                        NaN
#
#                                                        75%  \
# slug                                                   NaN
# name                                                   NaN
# profile                                                NaN
# language                                               NaN
# published_at                 2021-02-15 22:09:20.345250048
# contract_type                                          NaN
# experience_level_minimum                               3.0
# department                                             NaN
# remote                                                 NaN
# objectID                                               NaN
# website.reference                                      NaN
# organization.name                                      NaN
# organization.reference                                 NaN
# organization.size.en                                   NaN
# sectors_name.en                                        NaN
# contract_type_names.en                                 NaN
# office.city                                            NaN
# office.district                                        NaN
# office.state                                           NaN
# office.country                                         NaN
# office.country_code                                    NaN
# profession.name.en                                     NaN
# profession.category.en                                 NaN
# profession_name.en.Business                            NaN
# _geoloc.lat                                      48.882571
# _geoloc.lng                                       2.350552
# sectors                                                NaN
# sectors_parents                                        NaN
#
#                                                     max       std
# slug                                                NaN       NaN
# name                                                NaN       NaN
# profile                                             NaN       NaN
# language                                            NaN       NaN
# published_at                 2021-02-19 11:57:57.889000       NaN
# contract_type                                       NaN       NaN
# experience_level_minimum                           10.0  1.777234
# department                                          NaN       NaN
# remote                                              NaN       NaN
# objectID                                            NaN       NaN
# website.reference                                   NaN       NaN
# organization.name                                   NaN       NaN
# organization.reference                              NaN       NaN
# organization.size.en                                NaN       NaN
# sectors_name.en                                     NaN       NaN
# contract_type_names.en                              NaN       NaN
# office.city                                         NaN       NaN
# office.district                                     NaN       NaN
# office.state                                        NaN       NaN
# office.country                                      NaN       NaN
# office.country_code                                 NaN       NaN
# profession.name.en                                  NaN       NaN
# profession.category.en                              NaN       NaN
# profession_name.en.Business                         NaN       NaN
# _geoloc.lat                                   48.967775  0.025509
# _geoloc.lng                                    2.547917   0.04601
# sectors                                             NaN       NaN
# sectors_parents                                     NaN       NaN

# %% [markdown]
# ## Analyzing the data

# %% [markdown]
# ### Minimum experience required

# %%
jobs["experience_level_minimum"].describe(include="all",datetime_is_numeric=True).T
# Out:
# count    240.000000
# mean       1.479167
# std        1.777234
# min        0.000000
# 25%        0.000000
# 50%        0.750000
# 75%        3.000000
# max       10.000000
# Name: experience_level_minimum, dtype: float64

# %%
# Plotting an histogram with the distribution of the publication dates
fig = plt.figure(figsize=(16,6))
n, bins, patches = plt.hist(jobs["experience_level_minimum"])
plt.xticks(bins)
plt.show()

# %% [markdown]
# As a conclusion, it cheer me up to see that most of the jobs allow people with equal or less than 1 year of experience.

# %% [markdown]
# ### Publication dates

# %% [markdown]
# #### The publication dates shows us that the values are as fresh as January 12th January, proving that the

# %%
jobs["published_at"].describe(datetime_is_numeric=True).T
# Out:
# count                              240
# mean     2021-02-06 01:33:48.855312384
# min         2021-01-12 17:08:16.849000
# 25%      2021-01-28 10:27:26.335749888
# 50%      2021-02-08 16:20:10.178500096
# 75%      2021-02-15 22:09:20.345250048
# max         2021-02-19 11:57:57.889000
# Name: published_at, dtype: object

# %%
# Plotting an histogram with the distribution of the publication dates
fig = plt.figure(figsize=(16,6))
n, bins, patches = plt.hist(jobs["published_at"])
plt.xticks(bins)
plt.show()

# %% [markdown]
# ### Location

# %% [markdown]
# #### Plotting a map to visualize where are situated the most of the job offers in Paris

# %% [markdown]
# #### Is the job remote or not ?

# %%
# In total numbers
jobs["remote"].value_counts()
# Out:
# no          142
# partial      49
# punctual     43
# fulltime      6
# Name: remote, dtype: int64

# %%
# In percentage of the total
jobs["remote"].value_counts()/jobs["remote"].count()
# Out:
# no          0.591667
# partial     0.204167
# punctual    0.179167
# fulltime    0.025000
# Name: remote, dtype: float64

# %% [markdown]
# ### Jobs per company

# %%
jobs.groupby(by="organization.name").count().sort_values(by="name",ascending=False).T
# Out:
# organization.name            Deezer  Converteo  Deloitte  Banque de France  \
# slug                              7          6         5                 5
# name                              7          6         5                 5
# profile                           7          6         5                 5
# language                          7          6         5                 5
# published_at                      7          6         5                 5
# contract_type                     7          6         5                 5
# experience_level_minimum          7          6         5                 5
# department                        0          6         0                 0
# remote                            7          6         5                 5
# objectID                          7          6         5                 5
# website.reference                 7          6         5                 5
# organization.reference            7          6         5                 5
# organization.size.en              7          6         5                 5
# contract_type_names.en            7          6         5                 5
# office.city                       7          6         5                 5
# office.district                   7          6         5                 5
# office.state                      7          6         5                 5
# office.country                    7          6         5                 5
# office.country_code               7          6         5                 5
# profession.name.en                7          6         5                 5
# profession.category.en            7          6         5                 5
# profession_name.en.Business       0          0         0                 1
# _geoloc.lat                       7          6         5                 5
# _geoloc.lng                       7          6         5                 5
# sectors                           7          6         5                 5
# sectors_parents                   7          6         5                 5
#
# organization.name            Orange  Voodoo  Elevate   Oscaro  \
# slug                              4       4         4       4
# name                              4       4         4       4
# profile                           4       4         4       4
# language                          4       4         4       4
# published_at                      4       4         4       4
# contract_type                     4       4         4       4
# experience_level_minimum          4       4         4       4
# department                        0       4         4       0
# remote                            4       4         4       4
# objectID                          4       4         4       4
# website.reference                 4       4         4       4
# organization.reference            4       4         4       4
# organization.size.en              4       4         4       4
# contract_type_names.en            4       4         4       4
# office.city                       4       4         4       4
# office.district                   4       4         4       4
# office.state                      4       4         4       4
# office.country                    4       4         4       4
# office.country_code               4       4         4       4
# profession.name.en                4       4         4       4
# profession.category.en            4       4         4       4
# profession_name.en.Business       0       0         0       0
# _geoloc.lat                       4       4         4       4
# _geoloc.lng                       4       4         4       4
# sectors                           4       4         4       4
# sectors_parents                   4       4         4       4
#
# organization.name            Vestiaire Collective  \
# slug                                            4
# name                                            4
# profile                                         4
# language                                        4
# published_at                                    4
# contract_type                                   4
# experience_level_minimum                        4
# department                                      4
# remote                                          4
# objectID                                        4
# website.reference                               4
# organization.reference                          4
# organization.size.en                            4
# contract_type_names.en                          4
# office.city                                     4
# office.district                                 4
# office.state                                    4
# office.country                                  4
# office.country_code                             4
# profession.name.en                              4
# profession.category.en                          4
# profession_name.en.Business                     0
# _geoloc.lat                                     4
# _geoloc.lng                                     4
# sectors                                         4
# sectors_parents                                 4
#
# organization.name            Adot (anciennement Adotmob)  ...  \
# slug                                                   4  ...
# name                                                   4  ...
# profile                                                4  ...
# language                                               4  ...
# published_at                                           4  ...
# contract_type                                          4  ...
# experience_level_minimum                               4  ...
# department                                             4  ...
# remote                                                 4  ...
# objectID                                               4  ...
# website.reference                                      4  ...
# organization.reference                                 4  ...
# organization.size.en                                   4  ...
# contract_type_names.en                                 4  ...
# office.city                                            4  ...
# office.district                                        4  ...
# office.state                                           4  ...
# office.country                                         4  ...
# office.country_code                                    4  ...
# profession.name.en                                     4  ...
# profession.category.en                                 4  ...
# profession_name.en.Business                            0  ...
# _geoloc.lat                                            4  ...
# _geoloc.lng                                            4  ...
# sectors                                                4  ...
# sectors_parents                                        4  ...
#
# organization.name            Kili Technology   KLEE GROUP  Jobandtalent  \
# slug                                        1           1             1
# name                                        1           1             1
# profile                                     1           1             1
# language                                    1           1             1
# published_at                                1           1             1
# contract_type                               1           1             1
# experience_level_minimum                    1           1             1
# department                                  0           1             1
# remote                                      1           1             1
# objectID                                    1           1             1
# website.reference                           1           1             1
# organization.reference                      1           1             1
# organization.size.en                        1           1             1
# contract_type_names.en                      1           1             1
# office.city                                 1           1             1
# office.district                             1           1             1
# office.state                                1           1             1
# office.country                              1           1             1
# office.country_code                         1           1             1
# profession.name.en                          1           1             1
# profession.category.en                      1           1             1
# profession_name.en.Business                 1           0             0
# _geoloc.lat                                 1           1             1
# _geoloc.lng                                 1           1             1
# sectors                                     1           1             1
# sectors_parents                             1           1             1
#
# organization.name            Heetch  Hager Group  HUMENSIS  HAPPN  Gymlib  \
# slug                              1            1         1      1       1
# name                              1            1         1      1       1
# profile                           1            1         1      1       1
# language                          1            1         1      1       1
# published_at                      1            1         1      1       1
# contract_type                     1            1         1      1       1
# experience_level_minimum          1            1         1      1       1
# department                        1            0         1      1       1
# remote                            1            1         1      1       1
# objectID                          1            1         1      1       1
# website.reference                 1            1         1      1       1
# organization.reference            1            1         1      1       1
# organization.size.en              1            1         1      1       1
# contract_type_names.en            1            1         1      1       1
# office.city                       1            1         1      1       1
# office.district                   1            1         1      1       1
# office.state                      1            1         1      1       1
# office.country                    1            1         1      1       1
# office.country_code               1            1         1      1       1
# profession.name.en                1            1         1      1       1
# profession.category.en            1            1         1      1       1
# profession_name.en.Business       0            0         0      0       1
# _geoloc.lat                       1            1         1      1       1
# _geoloc.lng                       1            1         1      1       1
# sectors                           1            1         1      1       1
# sectors_parents                   1            1         1      1       1
#
# organization.name            Groupe Ingena  sennder France
# slug                                     1               1
# name                                     1               1
# profile                                  1               0
# language                                 1               1
# published_at                             1               1
# contract_type                            1               1
# experience_level_minimum                 1               1
# department                               0               0
# remote                                   1               1
# objectID                                 1               1
# website.reference                        1               1
# organization.reference                   1               1
# organization.size.en                     1               1
# contract_type_names.en                   1               1
# office.city                              1               1
# office.district                          1               1
# office.state                             1               1
# office.country                           1               1
# office.country_code                      1               1
# profession.name.en                       1               1
# profession.category.en                   1               1
# profession_name.en.Business              0               0
# _geoloc.lat                              1               1
# _geoloc.lng                              1               1
# sectors                                  1               1
# sectors_parents                          1               1
#
# [26 rows x 157 columns]

# %% [markdown]
# With this analysis, I may conclude that if I apply for the 10 companies that have the most number of Data positions open, I might have more chance of being matched with their open positions.

# %% [markdown]
# ### Sectors

# %% [markdown]
# #### Analyzing the sectors that appears the most in the job offers.

# %%
sectors_count_series = jobs.sectors.apply(lambda x: pd.value_counts(x.split(" / ")),0).sum(axis = 0).sort_values(ascending = False)
sectors_count_series
# Out:
# Big Data                  49.0
# Digital                   46.0
# E-commerce                38.0
# IT                        31.0
# Cloud Services            29.0
#                           ...
# Cultural Institutions      1.0
# NGO                        1.0
# Supply Chain               1.0
# Sports                     1.0
# Commercial Real Estate     1.0
# Length: 78, dtype: float64

# %%
# Now in percentage of the job offers scraped:
sectors_count_series_perc = round(100*sectors_count_series/jobs.count()[0],2)
sectors_count_series_perc
# Out:
# Big Data                  20.42
# Digital                   19.17
# E-commerce                15.83
# IT                        12.92
# Cloud Services            12.08
#                           ...
# Cultural Institutions      0.42
# NGO                        0.42
# Supply Chain               0.42
# Sports                     0.42
# Commercial Real Estate     0.42
# Length: 78, dtype: float64

# %%
# Libraries
import squarify

# Creating the plot from a data frame
fig = plt.figure(figsize=(20,10))
squarify.plot(sizes=sectors_count_series, label=sectors_count_series.index, value=sectors_count_series, alpha=0.8)
plt.axis('on')
plt.show()

# %% [markdown]
# # Saving file to csv

# %%
jobs.to_csv("jobs.csv")

# %% [markdown]
# # Exporting to SQL

# %%
import pymysql
from sqlalchemy import create_engine
from getpass import getpass

# %%
# SQL credentials
username='root'
server='localhost'
database='welcometothejungle'
password=getpass()
# Out:
# ········

# %%
# Creation of the engine
engine=create_engine(f"mysql+pymysql://{username}:{password}@{server}/{database}")

# %%
#inspecting the engine
from sqlalchemy import inspect
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['jobs']

# %%
jobs.to_sql('jobs', engine, if_exists='replace', index=False)
